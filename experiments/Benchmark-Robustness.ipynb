# %%
import timm
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from medmnist import INFO
import numpy as np
import faiss
import copy
from tqdm import tqdm 

import warnings
warnings.filterwarnings("ignore")

# %%
import torch
torch.cuda.set_device(0)
torch.cuda.current_device()
# Out:
# 0

# %%
from base_models import * 

# %load_ext autoreload
# %autoreload 1

# %%
CHANNELS = 1
N_CLASSES = 2
N_EPOCHS = 15

# DATASET_NAME = "PneumoniaMNIST"
# DATASET_NAME = "DermaMNIST" 
# DATASET_ID = "dermamnist"
DATASET_NAME = "BreastMNIST"
DATASET_ID = "breastmnist"

# %% [markdown]
# ### Data Loading

# %%
print(f"Step 1: Loading {DATASET_NAME} dataset with resize transform...")

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

info = INFO[DATASET_ID]
DataClass = getattr(__import__('medmnist'), info['python_class'])

device = torch.device('cuda:0')

train_dataset = DataClass(split='train', transform=transform, download=True, size=224)
val_dataset   = DataClass(split='val',   transform=transform, download=True, size=224)
test_dataset  = DataClass(split='test',  transform=transform, download=True, size=224)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=64, shuffle=False)
test_loader  = DataLoader(test_dataset,  batch_size=1, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Validation samples: {len(val_dataset)}, Test samples: {len(test_dataset)}")
# Out:
# Step 1: Loading BreastMNIST dataset with resize transform...
# Train samples: 546, Validation samples: 78, Test samples: 156

# %%
def train_model(model_class, seed, epochs=10):
    torch.manual_seed(seed)
    model = model_class().to(device)
    print(f"\nTraining {model.__class__.__name__} with seed {seed} for {epochs} epochs...") 

    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

    for epoch in range(1, epochs + 1):
        model.train()
        total_loss = 0
        correct = 0
        total = 0

        for x, y in train_loader:
            x, y = x.to(device), y.squeeze().long().to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = F.cross_entropy(out, y)
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * x.size(0)
            preds = out.argmax(dim=1)
            correct += (preds == y).sum().item()
            total += x.size(0)

        avg_loss = total_loss / total
        accuracy = correct / total * 100
        print(f"Epoch {epoch}/{epochs} - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.2f}%")

    return copy.deepcopy(model.to('cpu'))

# %% [markdown]
# ### Define DESImage

# %%
from torch.nn.functional import softmax, cosine_similarity
from collections import Counter


class DESImage: 
    def __init__(self, dsel_dataset, pool): 
        self.dsel_dataset = dsel_dataset
        self.dsel_loader = DataLoader(dsel_dataset, batch_size=64, shuffle=False) 
        self.dino_model = timm.create_model('vit_base_patch16_224.dino', pretrained=True).to(device)
        self.dino_model.eval()  
        self.pool = pool 

        self.suspected_model_votes = [] 
        
        
    def dino_embedder(self, images):
        if images.shape[1] == 1:
            images = images.repeat(1, 3, 1, 1)
        return self.dino_model.forward_features(images)
        

    def fit(self): 
        dsel_embeddings = []
        dsel_labels = []
    
        with torch.no_grad():
            for imgs, labels in self.dsel_loader:
                imgs = imgs.to(device)
                embs = self.dino_embedder(imgs).cpu()  # shape: [B, seq_len, 768]
                dsel_embeddings.append(embs)
                dsel_labels.append(labels)
    
        # Keep as tensor
        dsel_embeddings_tensor = torch.cat(dsel_embeddings).detach().cpu()  # shape: [N, seq_len, 768]
        cls_tensor = dsel_embeddings_tensor[:, 0, :]  # CLS token only, shape: [N, 768]
    
        # Convert to NumPy
        cls_embeddings = np.ascontiguousarray(cls_tensor.numpy(), dtype='float32')
        self.dsel_embeddings = cls_embeddings
        self.dsel_labels = torch.cat(dsel_labels).numpy()
    
        # Sanity check
        print(type(cls_embeddings))  # should be <class 'numpy.ndarray'>
        print(cls_embeddings.dtype)  # float32
        print(cls_embeddings.flags['C_CONTIGUOUS'])  # True
    
        # Build FAISS index
        embedding_dim = cls_embeddings.shape[1]
        self.index = faiss.IndexFlatL2(embedding_dim)
        self.index.add(cls_embeddings)


    def get_output_size(self, model):
        """
        Returns the output size (number of classes) from various model architectures.
        """
        if hasattr(model, 'fc'):
            return model.fc.out_features
        elif hasattr(model, 'classifier'):
            if isinstance(model.classifier, nn.Sequential):
                return model.classifier[-1].out_features
            else:
                return model.classifier.out_features
        elif hasattr(model, 'heads'):  # ViT / DINO from torchvision
            return model.heads.head.out_features
        elif hasattr(model, 'head'):  # ViT/Swin from timm
            return model.head.out_features
        else:
            raise AttributeError("Cannot determine output size of the model.")


    def predict_weighted(self, test_img, k=7, return_logits=False):
        # Step 1: Get DINO embedding
        img_for_dino = test_img.unsqueeze(0).to(device)
        if img_for_dino.shape[1] == 1:
            img_for_dino = img_for_dino.repeat(1, 3, 1, 1)
        with torch.no_grad():
            test_emb = self.dino_model.forward_features(img_for_dino).cpu().numpy().astype('float32')
            test_emb = test_emb[:, 0, :]  # CLS token only
    
        # Step 2: Nearest neighbors in FAISS
        _, neighbors = self.index.search(test_emb, k)
        neighbor_idxs = neighbors[0]
        local_labels = self.dsel_labels[neighbor_idxs]
    
        # Step 3: Competence of classifiers
        competences = []
        for clf in self.pool:
            clf.eval()
            with torch.no_grad():
                roc_imgs = torch.stack([self.dsel_dataset[idx][0] for idx in neighbor_idxs]).to(device)
                outputs = clf(roc_imgs)
                preds = outputs.argmax(dim=1).cpu().numpy()
            correct = (preds == local_labels).sum()
            competence = correct / k
            competences.append(competence)
    
        # Normalize competences
        total_comp = sum(competences)
        if total_comp == 0:
            competences = [1.0 / len(self.pool)] * len(self.pool)
        else:
            competences = [c / total_comp for c in competences]
    
        # Step 4: Weighted sum of classifier outputs
        test_img = test_img.unsqueeze(0).to(device)  # Add batch dimension
        num_classes = self.get_output_size(self.pool[0].model)
        weighted_logits = torch.zeros(num_classes).to(device)
    
        for clf, weight in zip(self.pool, competences):
            clf.eval()
            with torch.no_grad():
                logits = clf(test_img).squeeze(0)
                weighted_logits += weight * logits
    
        if return_logits:
            return weighted_logits  # shape: (num_classes,)
        
        final_pred = weighted_logits.argmax().item()
        return final_pred

        from torch.nn.functional import softmax, cosine_similarity


    def print_attack_statistics(self):
        if not self.suspected_model_votes:
            print("No predictions made yet.")
            return
    
        total = len(self.suspected_model_votes)
        count = Counter(self.suspected_model_votes)
        print("\n Suspected Attacked Model Statistics:")
        for model_idx, votes in count.items():
            percent = 100.0 * votes / total
            print(f" - Model #{model_idx}: {votes}/{total} ({percent:.2f}%)")
            print(f" Suspected attacked model name: {self.pool[model_idx].__class__.__name__}")
    
        
    
    def predict_weighted_robust(self, test_img, k=7, return_logits=False):
        # Step 1: Get DINO embedding of the test image
        img_for_dino = test_img.unsqueeze(0).to(device)
        if img_for_dino.shape[1] == 1:
            img_for_dino = img_for_dino.repeat(1, 3, 1, 1)
        with torch.no_grad():
            test_emb = self.dino_model.forward_features(img_for_dino).cpu().numpy().astype('float32')
            test_emb = test_emb[:, 0, :]  # CLS token only
    
        # Step 2: Get Region of Competence (RoC) from FAISS
        _, neighbors = self.index.search(test_emb, k)
        neighbor_idxs = neighbors[0]
        local_labels = self.dsel_labels[neighbor_idxs]
        
        # Step 3: Get RoC images
        with torch.no_grad():
            roc_imgs = torch.stack([self.dsel_dataset[idx][0] for idx in neighbor_idxs]).to(device)
            # if roc_imgs.shape[1] == 1:
            #     roc_imgs = roc_imgs.repeat(1, 3, 1, 1)
    
        # Step 4: Evaluate classifiers — compute competence and softmax outputs
        competences = []
        soft_outputs = []
    
        for clf in self.pool:
            clf.eval()
            with torch.no_grad():
                # Competence from RoC
                outputs = clf(roc_imgs)
                preds = outputs.argmax(dim=1).cpu().numpy()
                correct = (preds == local_labels).sum()
                competence = correct / k
                competences.append(competence)
    
                # Softmax on test image
                logits = clf(test_img.unsqueeze(0).to(device)).squeeze(0)
                probs = softmax(logits, dim=0)
                soft_outputs.append(probs)
    
        # Step 5: Agreement filtering via cosine similarity to average prediction
        mean_probs = torch.stack(soft_outputs).mean(dim=0)
        mean_probs_normed = mean_probs / mean_probs.norm()
    
        similarities = []
        for probs in soft_outputs:
            probs_normed = probs / probs.norm()
            sim = cosine_similarity(probs_normed.unsqueeze(0), mean_probs_normed.unsqueeze(0), dim=1)
            similarities.append(sim.item())
    
        # Step 6: Combine competence and similarity
        alpha = 2.0  # adjust influence of agreement
        combined_scores = [c * np.exp(alpha * s) for c, s in zip(competences, similarities)]
    
        # Normalize scores to get weights
        total_score = sum(combined_scores)
        if total_score == 0:
            weights = [1.0 / len(self.pool)] * len(self.pool)
        else:
            weights = [s / total_score for s in combined_scores]
    
        # Step 7: Weighted aggregation of classifier predictions
        num_classes = self.get_output_size(self.pool[0].model)
        weighted_logits = torch.zeros(num_classes).to(device)
        for prob, weight in zip(soft_outputs, weights):
            weighted_logits += weight * prob
    
        # Step 8: Print the suspected attacked model
        min_sim_idx = int(np.argmin(similarities))
        self.suspected_model_votes.append(min_sim_idx) 
    
        if return_logits:
            return weighted_logits  # shape: (num_classes,)
        return weighted_logits.argmax().item()

# %% [markdown]
# ### Benchmark

# %%
from torch.utils.data import TensorDataset, DataLoader
from art.attacks.evasion import ProjectedGradientDescent
from art.estimators.classification import PyTorchClassifier
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score
from collections import defaultdict


def evaluate_classifiers(pool, test_dataset, n_classes):
    loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
    results = []

    for i, model in enumerate(pool):
        model = model.to(device)
        model.eval()
        y_true, y_pred, y_prob = [], [], []

        with torch.no_grad():
            for imgs, labels in loader:
                imgs, labels = imgs.to(device), labels.squeeze().long().to(device)
                outputs = model(imgs)
                preds = outputs.argmax(dim=1)
                probs = torch.softmax(outputs, dim=1)

                y_true.extend(labels.cpu().numpy())
                y_pred.extend(preds.cpu().numpy())
                y_prob.extend(probs.cpu().numpy())

        acc = (np.array(y_true) == np.array(y_pred)).mean() * 100
        f1 = f1_score(y_true, y_pred, average='macro') * 100
        try:
            auc = roc_auc_score(y_true, y_prob, multi_class='ovr') * 100
        except ValueError:
            auc = float('nan')  # Handle single-class test sets

        results.append({
            'classifier': model.__class__.__name__,
            'accuracy': acc,
            'f1': f1,
            'auc': auc,
        })

    return results

# %%
import time

total_start = time.time()  # ⏱️ Start timing 

SEEDS = [10, 33, 45, 67, 85, 99, 102, 129, 141, 167] 
# SEEDS = [10, 33]

all_results = defaultdict(list) 

des_metrics = {
    'accuracy': [],
    'f1': [],
    'auc': []
}

attacked_results = defaultdict(list)
des_attacked_metrics = {
    'accuracy': [],
    'f1': [],
    'auc': []
}

des_defense_metrics = {
    'accuracy': [],
    'f1': [],
    'auc': []
}


for seed in SEEDS: 
    print(f"\n--- Seed: {seed} ---")
    trained_resnet18 = train_model(lambda: ResNet18Classifier(N_CLASSES, CHANNELS).to(device), seed, N_EPOCHS) 
    trained_resnet34 = train_model(lambda: ResNet34Classifier(N_CLASSES, CHANNELS).to(device), seed, N_EPOCHS) 
    trained_resnet50 = train_model(lambda: ResNet50Classifier(N_CLASSES, CHANNELS), seed, N_EPOCHS) 
    trained_mobilenetv2 = train_model(lambda: MobileNetV2Classifier(N_CLASSES, CHANNELS).to(device), seed, N_EPOCHS) 
    trained_efficientnet = train_model(lambda: EfficientNetB0Classifier(N_CLASSES, CHANNELS), seed, N_EPOCHS) 
    trained_densenet201 = train_model(lambda: DenseNet201Classifier(N_CLASSES, CHANNELS), seed, N_EPOCHS)  
    trained_shufflenet = train_model(lambda: ShuffleNetClassifier(N_CLASSES, CHANNELS), seed, N_EPOCHS)
    trained_googlenet = train_model(lambda:GoogLeNetClassifier(N_CLASSES, CHANNELS), seed, N_EPOCHS) 

    pool = [
        trained_resnet18, 
        trained_resnet34, 
        trained_resnet50, 
        trained_mobilenetv2,
        trained_efficientnet, 
        trained_densenet201,
        trained_shufflenet,
        trained_googlenet
    ]

    seed_results = evaluate_classifiers(pool, test_dataset, N_CLASSES)

    for res in seed_results:
        all_results[res['classifier']].append(res)


    # Build DES model
    des_model = DESImage(val_dataset, pool)
    des_model.fit()

    # Evaluate on test set
    y_true, y_pred, y_prob = [], [], []

    for imgs, labels in tqdm(test_loader):
        img = imgs[0]
        label = labels.item()

        logits = des_model.predict_weighted(img, return_logits=True)
        probs = torch.softmax(logits, dim=0).cpu().numpy()
        pred = np.argmax(probs)

        y_true.append(label)
        y_pred.append(pred)
        y_prob.append(probs)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.vstack(y_prob)

    # Compute metrics
    acc = accuracy_score(y_true, y_pred) * 100
    f1 = f1_score(y_true, y_pred, average='macro') * 100
    try:
        auc = roc_auc_score(y_true, y_prob, multi_class='ovr') * 100
    except:
        auc = float('nan')

    print(f"DES Accuracy: {acc:.2f}%  | F1: {f1:.2f}%  | AUC: {auc:.2f}%")

    des_metrics['accuracy'].append(acc)
    des_metrics['f1'].append(f1)
    des_metrics['auc'].append(auc)

    ### Attack =============================================================================================
    target_model = pool[0]  
    target_model = target_model.to(device).eval() 

    dummy_optimizer = torch.optim.Adam(target_model.parameters())
    loss_fn = nn.CrossEntropyLoss() 

    # Wrap it for ART
    art_classifier = PyTorchClassifier(
        model=target_model,
        loss=loss_fn,
        optimizer=dummy_optimizer,
        input_shape=(1, 224, 28),  
        nb_classes=N_CLASSES,
        clip_values=(0.0, 1.0),
    )

    x_test = []
    y_test = []
    
    for img, label in test_dataset:
        x_test.append(img.numpy())
        y_test.append(label.item())
    
    x_test = np.array(x_test)
    y_test = np.array(y_test)

    pgd_attack = ProjectedGradientDescent(estimator=art_classifier, eps=0.01, eps_step=0.01, max_iter=100)
    x_test_adv = pgd_attack.generate(x=x_test)

    adv_tensor = torch.tensor(x_test_adv).float()
    labels_tensor = torch.tensor(y_test).long()
    adv_dataset = TensorDataset(adv_tensor, labels_tensor)

    adv_test_loader = DataLoader(adv_dataset, batch_size=1, shuffle=False)  

    seed_attack_results = evaluate_classifiers(pool, adv_dataset, N_CLASSES) 
    for res in seed_attack_results:
        attacked_results[res['classifier']].append(res)


    # Evaluate on test set
    y_true, y_pred, y_prob = [], [], []

    for imgs, labels in tqdm(adv_test_loader):
        img = imgs[0]
        label = labels.item()

        logits = des_model.predict_weighted(img, return_logits=True)
        probs = torch.softmax(logits, dim=0).cpu().numpy()
        pred = np.argmax(probs)

        y_true.append(label)
        y_pred.append(pred)
        y_prob.append(probs)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.vstack(y_prob)

    # Compute metrics
    acc = accuracy_score(y_true, y_pred) * 100
    f1 = f1_score(y_true, y_pred, average='macro') * 100
    try:
        auc = roc_auc_score(y_true, y_prob, multi_class='ovr') * 100
    except:
        auc = float('nan')

    print(f"DES Accuracy: {acc:.2f}%  | F1: {f1:.2f}%  | AUC: {auc:.2f}%")

    des_attacked_metrics['accuracy'].append(acc)
    des_attacked_metrics['f1'].append(f1)
    des_attacked_metrics['auc'].append(auc)


    # DEFENSE ======================================================
    y_true, y_pred, y_prob = [], [], []

    for imgs, labels in tqdm(adv_test_loader):
        img = imgs[0]
        label = labels.item()

        logits = des_model.predict_weighted_robust(img, return_logits=True)
        probs = torch.softmax(logits, dim=0).cpu().numpy()
        pred = np.argmax(probs)

        y_true.append(label)
        y_pred.append(pred)
        y_prob.append(probs)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.vstack(y_prob)

    des_model.print_attack_statistics()

    # Compute metrics
    acc = accuracy_score(y_true, y_pred) * 100
    f1 = f1_score(y_true, y_pred, average='macro') * 100
    try:
        auc = roc_auc_score(y_true, y_prob, multi_class='ovr') * 100
    except:
        auc = float('nan')

    print(f"DES Accuracy: {acc:.2f}%  | F1: {f1:.2f}%  | AUC: {auc:.2f}%")

    des_defense_metrics['accuracy'].append(acc)
    des_defense_metrics['f1'].append(f1)
    des_defense_metrics['auc'].append(auc)


total_end = time.time()
print(f"\n⏱️ Total time for all seeds: {(total_end - total_start) / 60:.2f} minutes")
# Out:
# --- Seed: 10 ---
#
# Training ResNet18Classifier with seed 10 for 15 epochs...
# Epoch 1/15 - Loss: 0.6939, Accuracy: 68.50%
# Epoch 2/15 - Loss: 0.3429, Accuracy: 87.55%
# Epoch 3/15 - Loss: 0.2507, Accuracy: 88.10%
# Epoch 4/15 - Loss: 0.1852, Accuracy: 92.12%
# Epoch 5/15 - Loss: 0.0947, Accuracy: 97.44%
# Epoch 6/15 - Loss: 0.0486, Accuracy: 97.99%
# Epoch 7/15 - Loss: 0.0319, Accuracy: 98.72%
# Epoch 8/15 - Loss: 0.0482, Accuracy: 98.17%
# Epoch 9/15 - Loss: 0.0419, Accuracy: 98.35%
# Epoch 10/15 - Loss: 0.0194, Accuracy: 99.63%
# Epoch 11/15 - Loss: 0.0187, Accuracy: 99.45%
# Epoch 12/15 - Loss: 0.0151, Accuracy: 99.82%
# Epoch 13/15 - Loss: 0.0133, Accuracy: 99.82%
# Epoch 14/15 - Loss: 0.0088, Accuracy: 99.82%
# Epoch 15/15 - Loss: 0.0199, Accuracy: 99.82%
#
# Training ResNet34Classifier with seed 10 for 15 epochs...
# Epoch 1/15 - Loss: 0.8100, Accuracy: 71.79%
# Epoch 2/15 - Loss: 0.3378, Accuracy: 87.91%
# Epoch 3/15 - Loss: 0.2304, Accuracy: 90.84%
# Epoch 4/15 - Loss: 0.1903, Accuracy: 92.31%
# Epoch 5/15 - Loss: 0.1283, Accuracy: 95.24%
# Epoch 6/15 - Loss: 0.1400, Accuracy: 94.32%
# Epoch 7/15 - Loss: 0.1184, Accuracy: 96.34%
# Epoch 8/15 - Loss: 0.1047, Accuracy: 95.79%
# Epoch 9/15 - Loss: 0.0662, Accuracy: 97.44%
# Epoch 10/15 - Loss: 0.0313, Accuracy: 98.90%
# Epoch 11/15 - Loss: 0.0138, Accuracy: 99.63%
# Epoch 12/15 - Loss: 0.0288, Accuracy: 99.27%
# Epoch 13/15 - Loss: 0.0192, Accuracy: 99.45%
# Epoch 14/15 - Loss: 0.0405, Accuracy: 99.08%
# Epoch 15/15 - Loss: 0.0242, Accuracy: 99.27%
#
# Training ResNet50Classifier with seed 10 for 15 epochs...
# Epoch 1/15 - Loss: 0.7529, Accuracy: 70.51%
# Epoch 2/15 - Loss: 0.4087, Accuracy: 82.05%
# Epoch 3/15 - Loss: 0.2871, Accuracy: 87.55%
# Epoch 4/15 - Loss: 0.1718, Accuracy: 91.76%
# Epoch 5/15 - Loss: 0.1591, Accuracy: 92.86%
# Epoch 6/15 - Loss: 0.1703, Accuracy: 92.67%
# Epoch 7/15 - Loss: 0.1781, Accuracy: 93.41%
# Epoch 8/15 - Loss: 0.1329, Accuracy: 94.32%
# Epoch 9/15 - Loss: 0.2833, Accuracy: 90.48%
# Epoch 10/15 - Loss: 0.2027, Accuracy: 92.67%
# Epoch 11/15 - Loss: 0.1136, Accuracy: 96.52%
# Epoch 12/15 - Loss: 0.0484, Accuracy: 98.35%
# Epoch 13/15 - Loss: 0.0336, Accuracy: 99.08%
# Epoch 14/15 - Loss: 0.0153, Accuracy: 99.82%
# Epoch 15/15 - Loss: 0.0030, Accuracy: 100.00%
#
# Training MobileNetV2Classifier with seed 10 for 15 epochs...
# Epoch 1/15 - Loss: 0.5234, Accuracy: 79.85%
# Epoch 2/15 - Loss: 0.2747, Accuracy: 88.46%
# Epoch 3/15 - Loss: 0.1320, Accuracy: 95.05%
# Epoch 4/15 - Loss: 0.0660, Accuracy: 97.62%
# Epoch 5/15 - Loss: 0.0681, Accuracy: 96.89%
# Epoch 6/15 - Loss: 0.0851, Accuracy: 96.89%
# Epoch 7/15 - Loss: 0.1303, Accuracy: 94.51%
# Epoch 8/15 - Loss: 0.0712, Accuracy: 98.17%
# Epoch 9/15 - Loss: 0.0230, Accuracy: 99.63%
# Epoch 10/15 - Loss: 0.0151, Accuracy: 99.63%
# Epoch 11/15 - Loss: 0.0300, Accuracy: 99.82%
# Epoch 12/15 - Loss: 0.0103, Accuracy: 99.63%
# Epoch 13/15 - Loss: 0.0085, Accuracy: 99.82%
# Epoch 14/15 - Loss: 0.0114, Accuracy: 99.63%
# Epoch 15/15 - Loss: 0.0109, Accuracy: 99.82%
#
# Training EfficientNetB0Classifier with seed 10 for 15 epochs...
# Epoch 1/15 - Loss: 0.4559, Accuracy: 79.30%
# Epoch 2/15 - Loss: 0.1673, Accuracy: 93.04%
# Epoch 3/15 - Loss: 0.1205, Accuracy: 95.42%
# Epoch 4/15 - Loss: 0.0829, Accuracy: 95.97%
# Epoch 5/15 - Loss: 0.0572, Accuracy: 97.80%
# Epoch 6/15 - Loss: 0.0444, Accuracy: 98.35%
# Epoch 7/15 - Loss: 0.0373, Accuracy: 98.90%
# Epoch 8/15 - Loss: 0.0449, Accuracy: 98.53%
# Epoch 9/15 - Loss: 0.0301, Accuracy: 98.72%
# Epoch 10/15 - Loss: 0.0179, Accuracy: 99.63%
# Epoch 11/15 - Loss: 0.0149, Accuracy: 99.63%
# Epoch 12/15 - Loss: 0.0264, Accuracy: 99.45%
# Epoch 13/15 - Loss: 0.0390, Accuracy: 97.99%
# Epoch 14/15 - Loss: 0.0347, Accuracy: 98.72%
# Epoch 15/15 - Loss: 0.0244, Accuracy: 99.27%
#
# Training DenseNet201Classifier with seed 10 for 15 epochs...
# Epoch 1/15 - Loss: 0.5695, Accuracy: 72.71%
# Epoch 2/15 - Loss: 0.3275, Accuracy: 85.35%
# Epoch 3/15 - Loss: 0.1959, Accuracy: 92.67%
# Epoch 4/15 - Loss: 0.1237, Accuracy: 95.97%
# Epoch 5/15 - Loss: 0.1173, Accuracy: 94.69%
# Epoch 6/15 - Loss: 0.1608, Accuracy: 94.14%
# Epoch 7/15 - Loss: 0.1111, Accuracy: 95.60%
# Epoch 8/15 - Loss: 0.0535, Accuracy: 98.17%
# Epoch 9/15 - Loss: 0.0291, Accuracy: 99.27%
# Epoch 10/15 - Loss: 0.0507, Accuracy: 98.35%
# Epoch 11/15 - Loss: 0.0313, Accuracy: 98.90%
# Epoch 12/15 - Loss: 0.0680, Accuracy: 97.62%
# Epoch 13/15 - Loss: 0.0341, Accuracy: 98.90%
# Epoch 14/15 - Loss: 0.0702, Accuracy: 97.07%
# Epoch 15/15 - Loss: 0.0423, Accuracy: 98.72%
#
# Training ShuffleNetClassifier with seed 10 for 15 epochs...
# Epoch 1/15 - Loss: 0.6202, Accuracy: 73.08%
# Epoch 2/15 - Loss: 0.4385, Accuracy: 73.08%
# Epoch 3/15 - Loss: 0.2964, Accuracy: 77.84%
# Epoch 4/15 - Loss: 0.2195, Accuracy: 91.21%
# Epoch 5/15 - Loss: 0.1591, Accuracy: 99.08%
# Epoch 6/15 - Loss: 0.0977, Accuracy: 99.82%
# Epoch 7/15 - Loss: 0.0498, Accuracy: 100.00%
# Epoch 8/15 - Loss: 0.0245, Accuracy: 100.00%
# Epoch 9/15 - Loss: 0.0143, Accuracy: 100.00%
# Epoch 10/15 - Loss: 0.0073, Accuracy: 100.00%
# Epoch 11/15 - Loss: 0.0061, Accuracy: 100.00%
# Epoch 12/15 - Loss: 0.0115, Accuracy: 99.63%
# Epoch 13/15 - Loss: 0.0542, Accuracy: 98.17%
# Epoch 14/15 - Loss: 0.0889, Accuracy: 96.70%
# Epoch 15/15 - Loss: 0.0846, Accuracy: 97.07%
#
# Training GoogLeNetClassifier with seed 10 for 15 epochs...
# Epoch 1/15 - Loss: 0.4630, Accuracy: 78.21%
# Epoch 2/15 - Loss: 0.2213, Accuracy: 90.84%
# Epoch 3/15 - Loss: 0.1056, Accuracy: 95.79%
# Epoch 4/15 - Loss: 0.0584, Accuracy: 97.99%
# Epoch 5/15 - Loss: 0.0639, Accuracy: 97.99%
# Epoch 6/15 - Loss: 0.1044, Accuracy: 95.60%
# Epoch 7/15 - Loss: 0.0940, Accuracy: 96.34%
# Epoch 8/15 - Loss: 0.0726, Accuracy: 97.07%
# Epoch 9/15 - Loss: 0.0522, Accuracy: 98.35%
# Epoch 10/15 - Loss: 0.0160, Accuracy: 99.82%
# Epoch 11/15 - Loss: 0.0154, Accuracy: 99.27%
# Epoch 12/15 - Loss: 0.0450, Accuracy: 98.90%
# Epoch 13/15 - Loss: 0.0324, Accuracy: 98.90%
# Epoch 14/15 - Loss: 0.0208, Accuracy: 99.27%
# Epoch 15/15 - Loss: 0.0127, Accuracy: 99.45%
# <class 'numpy.ndarray'>
# float32
# True
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:25<00:00,  6.00it/s]
# DES Accuracy: 90.38%  | F1: 87.49%  | AUC: nan%
# PGD - Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:25<00:00,  6.18it/s]
# DES Accuracy: 86.54%  | F1: 80.85%  | AUC: nan%
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:20<00:00,  7.64it/s]
#  Suspected Attacked Model Statistics:
#  - Model #1: 12/156 (7.69%)
#  Suspected attacked model name: ResNet34Classifier
#  - Model #2: 10/156 (6.41%)
#  Suspected attacked model name: ResNet50Classifier
#  - Model #0: 98/156 (62.82%)
#  Suspected attacked model name: ResNet18Classifier
#  - Model #5: 7/156 (4.49%)
#  Suspected attacked model name: DenseNet201Classifier
#  - Model #6: 12/156 (7.69%)
#  Suspected attacked model name: ShuffleNetClassifier
#  - Model #7: 10/156 (6.41%)
#  Suspected attacked model name: GoogLeNetClassifier
#  - Model #3: 5/156 (3.21%)
#  Suspected attacked model name: MobileNetV2Classifier
#  - Model #4: 2/156 (1.28%)
#  Suspected attacked model name: EfficientNetB0Classifier
# DES Accuracy: 90.38%  | F1: 86.84%  | AUC: nan%
#
# --- Seed: 33 ---
#
# Training ResNet18Classifier with seed 33 for 15 epochs...
# Epoch 1/15 - Loss: 0.6193, Accuracy: 75.82%
# Epoch 2/15 - Loss: 0.3308, Accuracy: 87.00%
# Epoch 3/15 - Loss: 0.2422, Accuracy: 91.94%
# Epoch 4/15 - Loss: 0.1323, Accuracy: 94.87%
# Epoch 5/15 - Loss: 0.0825, Accuracy: 97.07%
# Epoch 6/15 - Loss: 0.0414, Accuracy: 99.27%
# Epoch 7/15 - Loss: 0.0295, Accuracy: 99.08%
# Epoch 8/15 - Loss: 0.0352, Accuracy: 98.53%
# Epoch 9/15 - Loss: 0.0294, Accuracy: 99.27%
# Epoch 10/15 - Loss: 0.0357, Accuracy: 98.72%
# Epoch 11/15 - Loss: 0.0810, Accuracy: 97.44%
# Epoch 12/15 - Loss: 0.0998, Accuracy: 96.89%
# Epoch 13/15 - Loss: 0.0522, Accuracy: 98.53%
# Epoch 14/15 - Loss: 0.0559, Accuracy: 97.99%
# Epoch 15/15 - Loss: 0.0448, Accuracy: 98.17%
#
# Training ResNet34Classifier with seed 33 for 15 epochs...
# Epoch 1/15 - Loss: 0.7803, Accuracy: 74.18%
# Epoch 2/15 - Loss: 0.4235, Accuracy: 83.33%
# Epoch 3/15 - Loss: 0.3048, Accuracy: 86.45%
# Epoch 4/15 - Loss: 0.2200, Accuracy: 90.66%
# Epoch 5/15 - Loss: 0.1864, Accuracy: 92.67%
# Epoch 6/15 - Loss: 0.1574, Accuracy: 94.14%
# Epoch 7/15 - Loss: 0.0974, Accuracy: 95.79%
# Epoch 8/15 - Loss: 0.0518, Accuracy: 97.99%
# Epoch 9/15 - Loss: 0.0542, Accuracy: 98.17%
# Epoch 10/15 - Loss: 0.0941, Accuracy: 96.34%
# Epoch 11/15 - Loss: 0.1422, Accuracy: 94.14%
# Epoch 12/15 - Loss: 0.1544, Accuracy: 94.14%
# Epoch 13/15 - Loss: 0.0907, Accuracy: 96.89%
# Epoch 14/15 - Loss: 0.0692, Accuracy: 97.80%
# Epoch 15/15 - Loss: 0.0415, Accuracy: 97.99%
#
# Training ResNet50Classifier with seed 33 for 15 epochs...
# Epoch 1/15 - Loss: 0.6856, Accuracy: 71.06%
# Epoch 2/15 - Loss: 0.4083, Accuracy: 84.80%
# Epoch 3/15 - Loss: 0.3033, Accuracy: 88.83%
# Epoch 4/15 - Loss: 0.1764, Accuracy: 92.86%
# Epoch 5/15 - Loss: 0.1412, Accuracy: 94.51%
# Epoch 6/15 - Loss: 0.0866, Accuracy: 97.07%
# Epoch 7/15 - Loss: 0.0963, Accuracy: 96.52%
# Epoch 8/15 - Loss: 0.0746, Accuracy: 96.89%
# Epoch 9/15 - Loss: 0.1027, Accuracy: 94.87%
# Epoch 10/15 - Loss: 0.1016, Accuracy: 95.97%
# Epoch 11/15 - Loss: 0.0950, Accuracy: 96.52%
# Epoch 12/15 - Loss: 0.0784, Accuracy: 97.80%
# Epoch 13/15 - Loss: 0.0425, Accuracy: 98.90%
# Epoch 14/15 - Loss: 0.0291, Accuracy: 98.90%
# Epoch 15/15 - Loss: 0.0161, Accuracy: 99.45%
#
# Training MobileNetV2Classifier with seed 33 for 15 epochs...
# Epoch 1/15 - Loss: 0.6229, Accuracy: 70.88%
# Epoch 2/15 - Loss: 0.2995, Accuracy: 88.64%
# Epoch 3/15 - Loss: 0.1520, Accuracy: 94.87%
# Epoch 4/15 - Loss: 0.0857, Accuracy: 96.89%
# Epoch 5/15 - Loss: 0.0530, Accuracy: 97.99%
# Epoch 6/15 - Loss: 0.0293, Accuracy: 99.27%
# Epoch 7/15 - Loss: 0.0452, Accuracy: 98.35%
# Epoch 8/15 - Loss: 0.0303, Accuracy: 98.90%
# Epoch 9/15 - Loss: 0.0429, Accuracy: 98.35%
# Epoch 10/15 - Loss: 0.0369, Accuracy: 99.08%
# Epoch 11/15 - Loss: 0.0714, Accuracy: 98.17%
# Epoch 12/15 - Loss: 0.0818, Accuracy: 97.80%
# Epoch 13/15 - Loss: 0.0339, Accuracy: 98.72%
# Epoch 14/15 - Loss: 0.0176, Accuracy: 99.27%
# Epoch 15/15 - Loss: 0.0154, Accuracy: 99.45%
#
# Training EfficientNetB0Classifier with seed 33 for 15 epochs...
# Epoch 1/15 - Loss: 0.4819, Accuracy: 77.11%
# Epoch 2/15 - Loss: 0.1705, Accuracy: 94.69%
# Epoch 3/15 - Loss: 0.0741, Accuracy: 97.25%
# Epoch 4/15 - Loss: 0.0809, Accuracy: 96.89%
# Epoch 5/15 - Loss: 0.0509, Accuracy: 97.44%
# Epoch 6/15 - Loss: 0.1028, Accuracy: 96.34%
# Epoch 7/15 - Loss: 0.0720, Accuracy: 97.25%
# Epoch 8/15 - Loss: 0.0376, Accuracy: 99.08%
# Epoch 9/15 - Loss: 0.0262, Accuracy: 99.08%
# Epoch 10/15 - Loss: 0.0185, Accuracy: 99.27%
# Epoch 11/15 - Loss: 0.0236, Accuracy: 99.27%
# Epoch 12/15 - Loss: 0.0221, Accuracy: 99.27%
# Epoch 13/15 - Loss: 0.0306, Accuracy: 99.27%
# Epoch 14/15 - Loss: 0.0292, Accuracy: 99.08%
# Epoch 15/15 - Loss: 0.0612, Accuracy: 98.53%
#
# Training DenseNet201Classifier with seed 33 for 15 epochs...
# Epoch 1/15 - Loss: 0.5749, Accuracy: 70.51%
# Epoch 2/15 - Loss: 0.3020, Accuracy: 87.73%
# Epoch 3/15 - Loss: 0.2012, Accuracy: 91.76%
# Epoch 4/15 - Loss: 0.1165, Accuracy: 96.15%
# Epoch 5/15 - Loss: 0.1239, Accuracy: 95.42%
# Epoch 6/15 - Loss: 0.1072, Accuracy: 95.79%
# Epoch 7/15 - Loss: 0.0916, Accuracy: 97.44%
# Epoch 8/15 - Loss: 0.0656, Accuracy: 98.35%
# Epoch 9/15 - Loss: 0.0566, Accuracy: 97.80%
# Epoch 10/15 - Loss: 0.0665, Accuracy: 97.62%
# Epoch 11/15 - Loss: 0.0569, Accuracy: 98.17%
# Epoch 12/15 - Loss: 0.0584, Accuracy: 97.80%
# Epoch 13/15 - Loss: 0.0433, Accuracy: 98.53%
# Epoch 14/15 - Loss: 0.0343, Accuracy: 98.35%
# Epoch 15/15 - Loss: 0.0264, Accuracy: 99.45%
#
# Training ShuffleNetClassifier with seed 33 for 15 epochs...
# Epoch 1/15 - Loss: 0.6189, Accuracy: 73.08%
# Epoch 2/15 - Loss: 0.4388, Accuracy: 73.08%
# Epoch 3/15 - Loss: 0.3080, Accuracy: 76.92%
# Epoch 4/15 - Loss: 0.2168, Accuracy: 91.94%
# Epoch 5/15 - Loss: 0.1456, Accuracy: 96.70%
# Epoch 6/15 - Loss: 0.0889, Accuracy: 97.07%
# Epoch 7/15 - Loss: 0.0632, Accuracy: 98.90%
# Epoch 8/15 - Loss: 0.0298, Accuracy: 99.82%
# Epoch 9/15 - Loss: 0.0186, Accuracy: 99.82%
# Epoch 10/15 - Loss: 0.0173, Accuracy: 99.82%
# Epoch 11/15 - Loss: 0.0162, Accuracy: 100.00%
# Epoch 12/15 - Loss: 0.0093, Accuracy: 99.82%
# Epoch 13/15 - Loss: 0.0268, Accuracy: 99.27%
# Epoch 14/15 - Loss: 0.0664, Accuracy: 98.35%
# Epoch 15/15 - Loss: 0.0581, Accuracy: 98.17%
#
# Training GoogLeNetClassifier with seed 33 for 15 epochs...
# Epoch 1/15 - Loss: 0.4623, Accuracy: 78.57%
# Epoch 2/15 - Loss: 0.2583, Accuracy: 90.11%
# Epoch 3/15 - Loss: 0.1369, Accuracy: 93.96%
# Epoch 4/15 - Loss: 0.0750, Accuracy: 96.89%
# Epoch 5/15 - Loss: 0.0435, Accuracy: 98.35%
# Epoch 6/15 - Loss: 0.0876, Accuracy: 97.07%
# Epoch 7/15 - Loss: 0.0506, Accuracy: 98.53%
# Epoch 8/15 - Loss: 0.0239, Accuracy: 99.45%
# Epoch 9/15 - Loss: 0.0236, Accuracy: 99.27%
# Epoch 10/15 - Loss: 0.0571, Accuracy: 97.80%
# Epoch 11/15 - Loss: 0.0690, Accuracy: 97.44%
# Epoch 12/15 - Loss: 0.0625, Accuracy: 97.62%
# Epoch 13/15 - Loss: 0.0660, Accuracy: 97.25%
# Epoch 14/15 - Loss: 0.0485, Accuracy: 98.35%
# Epoch 15/15 - Loss: 0.0426, Accuracy: 98.90%
# <class 'numpy.ndarray'>
# float32
# True
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.29it/s]
# DES Accuracy: 91.03%  | F1: 88.03%  | AUC: nan%
# PGD - Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.34it/s]
# DES Accuracy: 85.90%  | F1: 79.74%  | AUC: nan%
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:20<00:00,  7.64it/s]
#  Suspected Attacked Model Statistics:
#  - Model #2: 13/156 (8.33%)
#  Suspected attacked model name: ResNet50Classifier
#  - Model #0: 93/156 (59.62%)
#  Suspected attacked model name: ResNet18Classifier
#  - Model #7: 27/156 (17.31%)
#  Suspected attacked model name: GoogLeNetClassifier
#  - Model #5: 12/156 (7.69%)
#  Suspected attacked model name: DenseNet201Classifier
#  - Model #6: 4/156 (2.56%)
#  Suspected attacked model name: ShuffleNetClassifier
#  - Model #1: 4/156 (2.56%)
#  Suspected attacked model name: ResNet34Classifier
#  - Model #4: 3/156 (1.92%)
#  Suspected attacked model name: EfficientNetB0Classifier
# DES Accuracy: 88.46%  | F1: 84.06%  | AUC: nan%
#
# --- Seed: 45 ---
#
# Training ResNet18Classifier with seed 45 for 15 epochs...
# Epoch 1/15 - Loss: 0.6267, Accuracy: 76.74%
# Epoch 2/15 - Loss: 0.2816, Accuracy: 89.19%
# Epoch 3/15 - Loss: 0.1562, Accuracy: 92.67%
# Epoch 4/15 - Loss: 0.0975, Accuracy: 96.15%
# Epoch 5/15 - Loss: 0.0617, Accuracy: 97.99%
# Epoch 6/15 - Loss: 0.0464, Accuracy: 97.99%
# Epoch 7/15 - Loss: 0.0490, Accuracy: 97.99%
# Epoch 8/15 - Loss: 0.0719, Accuracy: 98.35%
# Epoch 9/15 - Loss: 0.0996, Accuracy: 97.07%
# Epoch 10/15 - Loss: 0.0629, Accuracy: 97.80%
# Epoch 11/15 - Loss: 0.0768, Accuracy: 96.70%
# Epoch 12/15 - Loss: 0.0558, Accuracy: 98.53%
# Epoch 13/15 - Loss: 0.0263, Accuracy: 99.27%
# Epoch 14/15 - Loss: 0.0329, Accuracy: 98.72%
# Epoch 15/15 - Loss: 0.0345, Accuracy: 98.90%
#
# Training ResNet34Classifier with seed 45 for 15 epochs...
# Epoch 1/15 - Loss: 0.7728, Accuracy: 70.88%
# Epoch 2/15 - Loss: 0.3546, Accuracy: 87.55%
# Epoch 3/15 - Loss: 0.3109, Accuracy: 88.28%
# Epoch 4/15 - Loss: 0.1918, Accuracy: 93.22%
# Epoch 5/15 - Loss: 0.1436, Accuracy: 94.69%
# Epoch 6/15 - Loss: 0.1204, Accuracy: 95.60%
# Epoch 7/15 - Loss: 0.0968, Accuracy: 97.07%
# Epoch 8/15 - Loss: 0.0945, Accuracy: 96.70%
# Epoch 9/15 - Loss: 0.0539, Accuracy: 97.99%
# Epoch 10/15 - Loss: 0.0399, Accuracy: 98.53%
# Epoch 11/15 - Loss: 0.0466, Accuracy: 98.53%
# Epoch 12/15 - Loss: 0.0482, Accuracy: 98.35%
# Epoch 13/15 - Loss: 0.0726, Accuracy: 97.44%
# Epoch 14/15 - Loss: 0.0634, Accuracy: 98.17%
# Epoch 15/15 - Loss: 0.0348, Accuracy: 98.53%
#
# Training ResNet50Classifier with seed 45 for 15 epochs...
# Epoch 1/15 - Loss: 0.7693, Accuracy: 70.15%
# Epoch 2/15 - Loss: 0.3936, Accuracy: 84.25%
# Epoch 3/15 - Loss: 0.2672, Accuracy: 89.19%
# Epoch 4/15 - Loss: 0.1559, Accuracy: 94.87%
# Epoch 5/15 - Loss: 0.1309, Accuracy: 94.14%
# Epoch 6/15 - Loss: 0.0938, Accuracy: 96.52%
# Epoch 7/15 - Loss: 0.0499, Accuracy: 98.17%
# Epoch 8/15 - Loss: 0.0161, Accuracy: 99.82%
# Epoch 9/15 - Loss: 0.1467, Accuracy: 95.97%
# Epoch 10/15 - Loss: 0.1848, Accuracy: 93.22%
# Epoch 11/15 - Loss: 0.1941, Accuracy: 92.49%
# Epoch 12/15 - Loss: 0.1056, Accuracy: 96.15%
# Epoch 13/15 - Loss: 0.0593, Accuracy: 97.80%
# Epoch 14/15 - Loss: 0.0494, Accuracy: 97.99%
# Epoch 15/15 - Loss: 0.0346, Accuracy: 98.53%
#
# Training MobileNetV2Classifier with seed 45 for 15 epochs...
# Epoch 1/15 - Loss: 0.5513, Accuracy: 76.56%
# Epoch 2/15 - Loss: 0.3215, Accuracy: 85.90%
# Epoch 3/15 - Loss: 0.1457, Accuracy: 93.77%
# Epoch 4/15 - Loss: 0.0910, Accuracy: 95.60%
# Epoch 5/15 - Loss: 0.1671, Accuracy: 95.24%
# Epoch 6/15 - Loss: 0.0339, Accuracy: 98.90%
# Epoch 7/15 - Loss: 0.0278, Accuracy: 99.27%
# Epoch 8/15 - Loss: 0.0221, Accuracy: 99.45%
# Epoch 9/15 - Loss: 0.0133, Accuracy: 99.45%
# Epoch 10/15 - Loss: 0.0118, Accuracy: 99.45%
# Epoch 11/15 - Loss: 0.0053, Accuracy: 99.82%
# Epoch 12/15 - Loss: 0.0028, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0023, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0014, Accuracy: 100.00%
# Epoch 15/15 - Loss: 0.0039, Accuracy: 99.82%
#
# Training EfficientNetB0Classifier with seed 45 for 15 epochs...
# Epoch 1/15 - Loss: 0.4951, Accuracy: 76.37%
# Epoch 2/15 - Loss: 0.2072, Accuracy: 93.96%
# Epoch 3/15 - Loss: 0.1059, Accuracy: 95.79%
# Epoch 4/15 - Loss: 0.0869, Accuracy: 96.70%
# Epoch 5/15 - Loss: 0.0852, Accuracy: 96.52%
# Epoch 6/15 - Loss: 0.0647, Accuracy: 97.62%
# Epoch 7/15 - Loss: 0.0520, Accuracy: 97.80%
# Epoch 8/15 - Loss: 0.0532, Accuracy: 99.08%
# Epoch 9/15 - Loss: 0.0449, Accuracy: 98.72%
# Epoch 10/15 - Loss: 0.0415, Accuracy: 98.90%
# Epoch 11/15 - Loss: 0.0310, Accuracy: 98.72%
# Epoch 12/15 - Loss: 0.0158, Accuracy: 99.63%
# Epoch 13/15 - Loss: 0.0149, Accuracy: 99.27%
# Epoch 14/15 - Loss: 0.0305, Accuracy: 99.08%
# Epoch 15/15 - Loss: 0.0437, Accuracy: 99.08%
#
# Training DenseNet201Classifier with seed 45 for 15 epochs...
# Epoch 1/15 - Loss: 0.5126, Accuracy: 78.75%
# Epoch 2/15 - Loss: 0.3172, Accuracy: 86.08%
# Epoch 3/15 - Loss: 0.2706, Accuracy: 88.10%
# Epoch 4/15 - Loss: 0.1280, Accuracy: 95.60%
# Epoch 5/15 - Loss: 0.1046, Accuracy: 97.25%
# Epoch 6/15 - Loss: 0.1062, Accuracy: 95.42%
# Epoch 7/15 - Loss: 0.0684, Accuracy: 98.35%
# Epoch 8/15 - Loss: 0.0843, Accuracy: 97.80%
# Epoch 9/15 - Loss: 0.0954, Accuracy: 96.15%
# Epoch 10/15 - Loss: 0.0938, Accuracy: 96.89%
# Epoch 11/15 - Loss: 0.0615, Accuracy: 97.44%
# Epoch 12/15 - Loss: 0.0220, Accuracy: 99.63%
# Epoch 13/15 - Loss: 0.0222, Accuracy: 99.45%
# Epoch 14/15 - Loss: 0.0354, Accuracy: 98.72%
# Epoch 15/15 - Loss: 0.0472, Accuracy: 98.35%
#
# Training ShuffleNetClassifier with seed 45 for 15 epochs...
# Epoch 1/15 - Loss: 0.6167, Accuracy: 74.18%
# Epoch 2/15 - Loss: 0.4268, Accuracy: 73.44%
# Epoch 3/15 - Loss: 0.2963, Accuracy: 73.26%
# Epoch 4/15 - Loss: 0.2367, Accuracy: 90.66%
# Epoch 5/15 - Loss: 0.1964, Accuracy: 97.62%
# Epoch 6/15 - Loss: 0.1536, Accuracy: 99.27%
# Epoch 7/15 - Loss: 0.1052, Accuracy: 98.90%
# Epoch 8/15 - Loss: 0.0655, Accuracy: 99.82%
# Epoch 9/15 - Loss: 0.0337, Accuracy: 100.00%
# Epoch 10/15 - Loss: 0.0264, Accuracy: 99.82%
# Epoch 11/15 - Loss: 0.0226, Accuracy: 99.63%
# Epoch 12/15 - Loss: 0.0149, Accuracy: 99.82%
# Epoch 13/15 - Loss: 0.0164, Accuracy: 99.63%
# Epoch 14/15 - Loss: 0.0274, Accuracy: 99.08%
# Epoch 15/15 - Loss: 0.0692, Accuracy: 97.62%
#
# Training GoogLeNetClassifier with seed 45 for 15 epochs...
# Epoch 1/15 - Loss: 0.4798, Accuracy: 77.66%
# Epoch 2/15 - Loss: 0.2299, Accuracy: 90.29%
# Epoch 3/15 - Loss: 0.1348, Accuracy: 94.14%
# Epoch 4/15 - Loss: 0.1642, Accuracy: 93.77%
# Epoch 5/15 - Loss: 0.0794, Accuracy: 97.44%
# Epoch 6/15 - Loss: 0.0489, Accuracy: 97.62%
# Epoch 7/15 - Loss: 0.0576, Accuracy: 98.53%
# Epoch 8/15 - Loss: 0.0373, Accuracy: 98.72%
# Epoch 9/15 - Loss: 0.0651, Accuracy: 97.25%
# Epoch 10/15 - Loss: 0.0599, Accuracy: 98.17%
# Epoch 11/15 - Loss: 0.0432, Accuracy: 98.53%
# Epoch 12/15 - Loss: 0.0216, Accuracy: 99.27%
# Epoch 13/15 - Loss: 0.0134, Accuracy: 99.63%
# Epoch 14/15 - Loss: 0.0237, Accuracy: 99.08%
# Epoch 15/15 - Loss: 0.0466, Accuracy: 98.35%
# <class 'numpy.ndarray'>
# float32
# True
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.34it/s]
# DES Accuracy: 89.10%  | F1: 85.08%  | AUC: nan%
# PGD - Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.37it/s]
# DES Accuracy: 87.18%  | F1: 83.19%  | AUC: nan%
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:20<00:00,  7.59it/s]
#  Suspected Attacked Model Statistics:
#  - Model #0: 118/156 (75.64%)
#  Suspected attacked model name: ResNet18Classifier
#  - Model #7: 19/156 (12.18%)
#  Suspected attacked model name: GoogLeNetClassifier
#  - Model #4: 7/156 (4.49%)
#  Suspected attacked model name: EfficientNetB0Classifier
#  - Model #6: 5/156 (3.21%)
#  Suspected attacked model name: ShuffleNetClassifier
#  - Model #1: 1/156 (0.64%)
#  Suspected attacked model name: ResNet34Classifier
#  - Model #3: 1/156 (0.64%)
#  Suspected attacked model name: MobileNetV2Classifier
#  - Model #5: 4/156 (2.56%)
#  Suspected attacked model name: DenseNet201Classifier
#  - Model #2: 1/156 (0.64%)
#  Suspected attacked model name: ResNet50Classifier
# DES Accuracy: 90.38%  | F1: 87.49%  | AUC: nan%
#
# --- Seed: 67 ---
#
# Training ResNet18Classifier with seed 67 for 15 epochs...
# Epoch 1/15 - Loss: 0.7470, Accuracy: 68.13%
# Epoch 2/15 - Loss: 0.4301, Accuracy: 86.08%
# Epoch 3/15 - Loss: 0.2691, Accuracy: 88.64%
# Epoch 4/15 - Loss: 0.1611, Accuracy: 93.41%
# Epoch 5/15 - Loss: 0.0789, Accuracy: 97.99%
# Epoch 6/15 - Loss: 0.0513, Accuracy: 98.35%
# Epoch 7/15 - Loss: 0.0372, Accuracy: 98.72%
# Epoch 8/15 - Loss: 0.0406, Accuracy: 98.35%
# Epoch 9/15 - Loss: 0.0206, Accuracy: 99.45%
# Epoch 10/15 - Loss: 0.0129, Accuracy: 99.82%
# Epoch 11/15 - Loss: 0.0063, Accuracy: 100.00%
# Epoch 12/15 - Loss: 0.0024, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0049, Accuracy: 99.82%
# Epoch 14/15 - Loss: 0.0047, Accuracy: 100.00%
# Epoch 15/15 - Loss: 0.0022, Accuracy: 100.00%
#
# Training ResNet34Classifier with seed 67 for 15 epochs...
# Epoch 1/15 - Loss: 0.7629, Accuracy: 69.60%
# Epoch 2/15 - Loss: 0.3622, Accuracy: 84.25%
# Epoch 3/15 - Loss: 0.3176, Accuracy: 87.73%
# Epoch 4/15 - Loss: 0.2240, Accuracy: 91.94%
# Epoch 5/15 - Loss: 0.1790, Accuracy: 92.12%
# Epoch 6/15 - Loss: 0.1457, Accuracy: 94.51%
# Epoch 7/15 - Loss: 0.1185, Accuracy: 95.97%
# Epoch 8/15 - Loss: 0.1033, Accuracy: 96.15%
# Epoch 9/15 - Loss: 0.1253, Accuracy: 94.69%
# Epoch 10/15 - Loss: 0.0659, Accuracy: 97.80%
# Epoch 11/15 - Loss: 0.0295, Accuracy: 99.27%
# Epoch 12/15 - Loss: 0.0215, Accuracy: 98.90%
# Epoch 13/15 - Loss: 0.0259, Accuracy: 98.90%
# Epoch 14/15 - Loss: 0.0126, Accuracy: 99.63%
# Epoch 15/15 - Loss: 0.0339, Accuracy: 99.45%
#
# Training ResNet50Classifier with seed 67 for 15 epochs...
# Epoch 1/15 - Loss: 0.7281, Accuracy: 71.61%
# Epoch 2/15 - Loss: 0.3668, Accuracy: 86.45%
# Epoch 3/15 - Loss: 0.2818, Accuracy: 88.64%
# Epoch 4/15 - Loss: 0.1997, Accuracy: 91.94%
# Epoch 5/15 - Loss: 0.1790, Accuracy: 93.77%
# Epoch 6/15 - Loss: 0.1480, Accuracy: 95.05%
# Epoch 7/15 - Loss: 0.0948, Accuracy: 96.15%
# Epoch 8/15 - Loss: 0.1135, Accuracy: 95.42%
# Epoch 9/15 - Loss: 0.0913, Accuracy: 97.25%
# Epoch 10/15 - Loss: 0.1265, Accuracy: 96.70%
# Epoch 11/15 - Loss: 0.1422, Accuracy: 93.77%
# Epoch 12/15 - Loss: 0.1162, Accuracy: 95.42%
# Epoch 13/15 - Loss: 0.1117, Accuracy: 95.97%
# Epoch 14/15 - Loss: 0.1004, Accuracy: 96.70%
# Epoch 15/15 - Loss: 0.0400, Accuracy: 98.72%
#
# Training MobileNetV2Classifier with seed 67 for 15 epochs...
# Epoch 1/15 - Loss: 0.5414, Accuracy: 78.21%
# Epoch 2/15 - Loss: 0.2771, Accuracy: 87.55%
# Epoch 3/15 - Loss: 0.1704, Accuracy: 92.67%
# Epoch 4/15 - Loss: 0.0695, Accuracy: 97.44%
# Epoch 5/15 - Loss: 0.0264, Accuracy: 99.08%
# Epoch 6/15 - Loss: 0.0199, Accuracy: 99.45%
# Epoch 7/15 - Loss: 0.0262, Accuracy: 99.08%
# Epoch 8/15 - Loss: 0.0623, Accuracy: 98.17%
# Epoch 9/15 - Loss: 0.0730, Accuracy: 97.62%
# Epoch 10/15 - Loss: 0.1010, Accuracy: 95.79%
# Epoch 11/15 - Loss: 0.0939, Accuracy: 96.52%
# Epoch 12/15 - Loss: 0.0531, Accuracy: 98.53%
# Epoch 13/15 - Loss: 0.0074, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0060, Accuracy: 100.00%
# Epoch 15/15 - Loss: 0.0030, Accuracy: 100.00%
#
# Training EfficientNetB0Classifier with seed 67 for 15 epochs...
# Epoch 1/15 - Loss: 0.5066, Accuracy: 75.64%
# Epoch 2/15 - Loss: 0.2065, Accuracy: 92.31%
# Epoch 3/15 - Loss: 0.0832, Accuracy: 97.44%
# Epoch 4/15 - Loss: 0.0718, Accuracy: 97.80%
# Epoch 5/15 - Loss: 0.0644, Accuracy: 97.62%
# Epoch 6/15 - Loss: 0.0642, Accuracy: 97.44%
# Epoch 7/15 - Loss: 0.0670, Accuracy: 97.62%
# Epoch 8/15 - Loss: 0.0616, Accuracy: 97.80%
# Epoch 9/15 - Loss: 0.0457, Accuracy: 98.53%
# Epoch 10/15 - Loss: 0.0340, Accuracy: 98.72%
# Epoch 11/15 - Loss: 0.0390, Accuracy: 98.17%
# Epoch 12/15 - Loss: 0.0385, Accuracy: 98.90%
# Epoch 13/15 - Loss: 0.0708, Accuracy: 98.72%
# Epoch 14/15 - Loss: 0.0268, Accuracy: 99.27%
# Epoch 15/15 - Loss: 0.0338, Accuracy: 99.27%
#
# Training DenseNet201Classifier with seed 67 for 15 epochs...
# Epoch 1/15 - Loss: 0.5059, Accuracy: 76.01%
# Epoch 2/15 - Loss: 0.3325, Accuracy: 86.45%
# Epoch 3/15 - Loss: 0.2860, Accuracy: 87.73%
# Epoch 4/15 - Loss: 0.1626, Accuracy: 94.51%
# Epoch 5/15 - Loss: 0.1175, Accuracy: 94.87%
# Epoch 6/15 - Loss: 0.1102, Accuracy: 95.97%
# Epoch 7/15 - Loss: 0.0869, Accuracy: 97.80%
# Epoch 8/15 - Loss: 0.0661, Accuracy: 97.44%
# Epoch 9/15 - Loss: 0.0596, Accuracy: 97.62%
# Epoch 10/15 - Loss: 0.1025, Accuracy: 96.52%
# Epoch 11/15 - Loss: 0.0876, Accuracy: 97.07%
# Epoch 12/15 - Loss: 0.1106, Accuracy: 95.79%
# Epoch 13/15 - Loss: 0.1056, Accuracy: 96.15%
# Epoch 14/15 - Loss: 0.0855, Accuracy: 97.07%
# Epoch 15/15 - Loss: 0.0817, Accuracy: 96.34%
#
# Training ShuffleNetClassifier with seed 67 for 15 epochs...
# Epoch 1/15 - Loss: 0.6206, Accuracy: 72.89%
# Epoch 2/15 - Loss: 0.4427, Accuracy: 82.78%
# Epoch 3/15 - Loss: 0.3102, Accuracy: 87.00%
# Epoch 4/15 - Loss: 0.2322, Accuracy: 94.32%
# Epoch 5/15 - Loss: 0.1786, Accuracy: 99.08%
# Epoch 6/15 - Loss: 0.1321, Accuracy: 98.17%
# Epoch 7/15 - Loss: 0.0907, Accuracy: 99.08%
# Epoch 8/15 - Loss: 0.0516, Accuracy: 99.82%
# Epoch 9/15 - Loss: 0.0330, Accuracy: 99.63%
# Epoch 10/15 - Loss: 0.0238, Accuracy: 99.63%
# Epoch 11/15 - Loss: 0.0201, Accuracy: 99.63%
# Epoch 12/15 - Loss: 0.0120, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0070, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0056, Accuracy: 100.00%
# Epoch 15/15 - Loss: 0.0040, Accuracy: 100.00%
#
# Training GoogLeNetClassifier with seed 67 for 15 epochs...
# Epoch 1/15 - Loss: 0.4774, Accuracy: 75.09%
# Epoch 2/15 - Loss: 0.1938, Accuracy: 92.86%
# Epoch 3/15 - Loss: 0.1002, Accuracy: 96.52%
# Epoch 4/15 - Loss: 0.0702, Accuracy: 97.80%
# Epoch 5/15 - Loss: 0.0585, Accuracy: 97.80%
# Epoch 6/15 - Loss: 0.0406, Accuracy: 98.53%
# Epoch 7/15 - Loss: 0.0309, Accuracy: 98.72%
# Epoch 8/15 - Loss: 0.0144, Accuracy: 99.63%
# Epoch 9/15 - Loss: 0.0291, Accuracy: 98.35%
# Epoch 10/15 - Loss: 0.0969, Accuracy: 97.07%
# Epoch 11/15 - Loss: 0.0801, Accuracy: 97.62%
# Epoch 12/15 - Loss: 0.0669, Accuracy: 96.70%
# Epoch 13/15 - Loss: 0.0346, Accuracy: 98.53%
# Epoch 14/15 - Loss: 0.0177, Accuracy: 99.27%
# Epoch 15/15 - Loss: 0.0131, Accuracy: 99.63%
# <class 'numpy.ndarray'>
# float32
# True
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:25<00:00,  6.20it/s]
# DES Accuracy: 91.67%  | F1: 89.16%  | AUC: nan%
# PGD - Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:25<00:00,  6.10it/s]
# DES Accuracy: 85.26%  | F1: 82.38%  | AUC: nan%
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:20<00:00,  7.55it/s]
#  Suspected Attacked Model Statistics:
#  - Model #0: 139/156 (89.10%)
#  Suspected attacked model name: ResNet18Classifier
#  - Model #6: 5/156 (3.21%)
#  Suspected attacked model name: ShuffleNetClassifier
#  - Model #5: 3/156 (1.92%)
#  Suspected attacked model name: DenseNet201Classifier
#  - Model #2: 4/156 (2.56%)
#  Suspected attacked model name: ResNet50Classifier
#  - Model #4: 1/156 (0.64%)
#  Suspected attacked model name: EfficientNetB0Classifier
#  - Model #1: 3/156 (1.92%)
#  Suspected attacked model name: ResNet34Classifier
#  - Model #3: 1/156 (0.64%)
#  Suspected attacked model name: MobileNetV2Classifier
# DES Accuracy: 92.31%  | F1: 90.07%  | AUC: nan%
#
# --- Seed: 85 ---
#
# Training ResNet18Classifier with seed 85 for 15 epochs...
# Epoch 1/15 - Loss: 0.7426, Accuracy: 73.63%
# Epoch 2/15 - Loss: 0.3649, Accuracy: 85.71%
# Epoch 3/15 - Loss: 0.1919, Accuracy: 93.22%
# Epoch 4/15 - Loss: 0.1167, Accuracy: 95.42%
# Epoch 5/15 - Loss: 0.1015, Accuracy: 95.97%
# Epoch 6/15 - Loss: 0.0585, Accuracy: 97.99%
# Epoch 7/15 - Loss: 0.0385, Accuracy: 98.53%
# Epoch 8/15 - Loss: 0.0227, Accuracy: 99.45%
# Epoch 9/15 - Loss: 0.0341, Accuracy: 99.08%
# Epoch 10/15 - Loss: 0.0267, Accuracy: 99.08%
# Epoch 11/15 - Loss: 0.0306, Accuracy: 98.90%
# Epoch 12/15 - Loss: 0.0196, Accuracy: 99.27%
# Epoch 13/15 - Loss: 0.0090, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0063, Accuracy: 99.82%
# Epoch 15/15 - Loss: 0.0043, Accuracy: 99.82%
#
# Training ResNet34Classifier with seed 85 for 15 epochs...
# Epoch 1/15 - Loss: 0.9211, Accuracy: 67.22%
# Epoch 2/15 - Loss: 0.4614, Accuracy: 80.40%
# Epoch 3/15 - Loss: 0.3787, Accuracy: 86.08%
# Epoch 4/15 - Loss: 0.2713, Accuracy: 89.01%
# Epoch 5/15 - Loss: 0.2488, Accuracy: 89.93%
# Epoch 6/15 - Loss: 0.1954, Accuracy: 93.59%
# Epoch 7/15 - Loss: 0.1422, Accuracy: 94.69%
# Epoch 8/15 - Loss: 0.1545, Accuracy: 93.59%
# Epoch 9/15 - Loss: 0.1597, Accuracy: 92.86%
# Epoch 10/15 - Loss: 0.1327, Accuracy: 94.87%
# Epoch 11/15 - Loss: 0.0999, Accuracy: 95.60%
# Epoch 12/15 - Loss: 0.0913, Accuracy: 96.70%
# Epoch 13/15 - Loss: 0.1135, Accuracy: 95.60%
# Epoch 14/15 - Loss: 0.1215, Accuracy: 95.60%
# Epoch 15/15 - Loss: 0.0709, Accuracy: 97.44%
#
# Training ResNet50Classifier with seed 85 for 15 epochs...
# Epoch 1/15 - Loss: 0.6821, Accuracy: 69.23%
# Epoch 2/15 - Loss: 0.3564, Accuracy: 82.60%
# Epoch 3/15 - Loss: 0.2264, Accuracy: 90.11%
# Epoch 4/15 - Loss: 0.1177, Accuracy: 95.42%
# Epoch 5/15 - Loss: 0.0955, Accuracy: 96.70%
# Epoch 6/15 - Loss: 0.1255, Accuracy: 94.69%
# Epoch 7/15 - Loss: 0.1312, Accuracy: 95.60%
# Epoch 8/15 - Loss: 0.0643, Accuracy: 98.35%
# Epoch 9/15 - Loss: 0.0274, Accuracy: 99.08%
# Epoch 10/15 - Loss: 0.0186, Accuracy: 98.90%
# Epoch 11/15 - Loss: 0.0227, Accuracy: 99.08%
# Epoch 12/15 - Loss: 0.0575, Accuracy: 97.25%
# Epoch 13/15 - Loss: 0.0687, Accuracy: 96.89%
# Epoch 14/15 - Loss: 0.0559, Accuracy: 98.53%
# Epoch 15/15 - Loss: 0.0809, Accuracy: 97.44%
#
# Training MobileNetV2Classifier with seed 85 for 15 epochs...
# Epoch 1/15 - Loss: 0.5520, Accuracy: 75.82%
# Epoch 2/15 - Loss: 0.3939, Accuracy: 83.88%
# Epoch 3/15 - Loss: 0.2095, Accuracy: 91.94%
# Epoch 4/15 - Loss: 0.0931, Accuracy: 95.97%
# Epoch 5/15 - Loss: 0.0315, Accuracy: 99.08%
# Epoch 6/15 - Loss: 0.0309, Accuracy: 98.72%
# Epoch 7/15 - Loss: 0.0504, Accuracy: 98.90%
# Epoch 8/15 - Loss: 0.0281, Accuracy: 98.90%
# Epoch 9/15 - Loss: 0.0196, Accuracy: 99.45%
# Epoch 10/15 - Loss: 0.0600, Accuracy: 97.80%
# Epoch 11/15 - Loss: 0.0225, Accuracy: 99.45%
# Epoch 12/15 - Loss: 0.0355, Accuracy: 98.17%
# Epoch 13/15 - Loss: 0.0137, Accuracy: 99.82%
# Epoch 14/15 - Loss: 0.0106, Accuracy: 99.82%
# Epoch 15/15 - Loss: 0.0110, Accuracy: 99.45%
#
# Training EfficientNetB0Classifier with seed 85 for 15 epochs...
# Epoch 1/15 - Loss: 0.5145, Accuracy: 76.19%
# Epoch 2/15 - Loss: 0.2259, Accuracy: 92.31%
# Epoch 3/15 - Loss: 0.0583, Accuracy: 98.53%
# Epoch 4/15 - Loss: 0.0601, Accuracy: 98.17%
# Epoch 5/15 - Loss: 0.0614, Accuracy: 97.44%
# Epoch 6/15 - Loss: 0.1136, Accuracy: 95.79%
# Epoch 7/15 - Loss: 0.0437, Accuracy: 98.72%
# Epoch 8/15 - Loss: 0.0221, Accuracy: 99.27%
# Epoch 9/15 - Loss: 0.0066, Accuracy: 100.00%
# Epoch 10/15 - Loss: 0.0150, Accuracy: 99.45%
# Epoch 11/15 - Loss: 0.0172, Accuracy: 99.63%
# Epoch 12/15 - Loss: 0.0177, Accuracy: 99.27%
# Epoch 13/15 - Loss: 0.0354, Accuracy: 98.72%
# Epoch 14/15 - Loss: 0.0444, Accuracy: 98.90%
# Epoch 15/15 - Loss: 0.0535, Accuracy: 98.53%
#
# Training DenseNet201Classifier with seed 85 for 15 epochs...
# Epoch 1/15 - Loss: 0.5276, Accuracy: 77.47%
# Epoch 2/15 - Loss: 0.2966, Accuracy: 88.64%
# Epoch 3/15 - Loss: 0.2431, Accuracy: 90.11%
# Epoch 4/15 - Loss: 0.1534, Accuracy: 94.69%
# Epoch 5/15 - Loss: 0.0789, Accuracy: 97.07%
# Epoch 6/15 - Loss: 0.0981, Accuracy: 96.70%
# Epoch 7/15 - Loss: 0.0985, Accuracy: 95.97%
# Epoch 8/15 - Loss: 0.0693, Accuracy: 97.80%
# Epoch 9/15 - Loss: 0.0493, Accuracy: 98.72%
# Epoch 10/15 - Loss: 0.0644, Accuracy: 97.44%
# Epoch 11/15 - Loss: 0.0980, Accuracy: 95.79%
# Epoch 12/15 - Loss: 0.1394, Accuracy: 94.51%
# Epoch 13/15 - Loss: 0.0774, Accuracy: 98.35%
# Epoch 14/15 - Loss: 0.0266, Accuracy: 98.90%
# Epoch 15/15 - Loss: 0.0402, Accuracy: 97.99%
#
# Training ShuffleNetClassifier with seed 85 for 15 epochs...
# Epoch 1/15 - Loss: 0.6118, Accuracy: 73.08%
# Epoch 2/15 - Loss: 0.4251, Accuracy: 73.08%
# Epoch 3/15 - Loss: 0.2989, Accuracy: 81.14%
# Epoch 4/15 - Loss: 0.2135, Accuracy: 94.69%
# Epoch 5/15 - Loss: 0.1332, Accuracy: 97.99%
# Epoch 6/15 - Loss: 0.0712, Accuracy: 99.08%
# Epoch 7/15 - Loss: 0.0394, Accuracy: 99.45%
# Epoch 8/15 - Loss: 0.0185, Accuracy: 100.00%
# Epoch 9/15 - Loss: 0.0073, Accuracy: 100.00%
# Epoch 10/15 - Loss: 0.0057, Accuracy: 100.00%
# Epoch 11/15 - Loss: 0.0031, Accuracy: 100.00%
# Epoch 12/15 - Loss: 0.0040, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0038, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0348, Accuracy: 98.72%
# Epoch 15/15 - Loss: 0.0415, Accuracy: 98.35%
#
# Training GoogLeNetClassifier with seed 85 for 15 epochs...
# Epoch 1/15 - Loss: 0.5026, Accuracy: 75.09%
# Epoch 2/15 - Loss: 0.1943, Accuracy: 92.31%
# Epoch 3/15 - Loss: 0.1217, Accuracy: 95.79%
# Epoch 4/15 - Loss: 0.0729, Accuracy: 96.89%
# Epoch 5/15 - Loss: 0.1308, Accuracy: 94.69%
# Epoch 6/15 - Loss: 0.1229, Accuracy: 94.14%
# Epoch 7/15 - Loss: 0.0875, Accuracy: 97.07%
# Epoch 8/15 - Loss: 0.0557, Accuracy: 98.35%
# Epoch 9/15 - Loss: 0.0145, Accuracy: 99.82%
# Epoch 10/15 - Loss: 0.0081, Accuracy: 100.00%
# Epoch 11/15 - Loss: 0.0034, Accuracy: 100.00%
# Epoch 12/15 - Loss: 0.0034, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0034, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0013, Accuracy: 100.00%
# Epoch 15/15 - Loss: 0.0008, Accuracy: 100.00%
# <class 'numpy.ndarray'>
# float32
# True
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.35it/s]
# DES Accuracy: 91.03%  | F1: 88.23%  | AUC: nan%
# PGD - Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:25<00:00,  6.16it/s]
# DES Accuracy: 81.41%  | F1: 76.55%  | AUC: nan%
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:20<00:00,  7.58it/s]
#  Suspected Attacked Model Statistics:
#  - Model #0: 141/156 (90.38%)
#  Suspected attacked model name: ResNet18Classifier
#  - Model #4: 2/156 (1.28%)
#  Suspected attacked model name: EfficientNetB0Classifier
#  - Model #2: 5/156 (3.21%)
#  Suspected attacked model name: ResNet50Classifier
#  - Model #5: 2/156 (1.28%)
#  Suspected attacked model name: DenseNet201Classifier
#  - Model #6: 2/156 (1.28%)
#  Suspected attacked model name: ShuffleNetClassifier
#  - Model #3: 3/156 (1.92%)
#  Suspected attacked model name: MobileNetV2Classifier
#  - Model #1: 1/156 (0.64%)
#  Suspected attacked model name: ResNet34Classifier
# DES Accuracy: 89.10%  | F1: 85.83%  | AUC: nan%
#
# --- Seed: 99 ---
#
# Training ResNet18Classifier with seed 99 for 15 epochs...
# Epoch 1/15 - Loss: 0.6628, Accuracy: 75.46%
# Epoch 2/15 - Loss: 0.3345, Accuracy: 87.73%
# Epoch 3/15 - Loss: 0.2206, Accuracy: 92.12%
# Epoch 4/15 - Loss: 0.1235, Accuracy: 95.60%
# Epoch 5/15 - Loss: 0.0926, Accuracy: 97.25%
# Epoch 6/15 - Loss: 0.0793, Accuracy: 97.80%
# Epoch 7/15 - Loss: 0.0406, Accuracy: 98.90%
# Epoch 8/15 - Loss: 0.0209, Accuracy: 99.63%
# Epoch 9/15 - Loss: 0.0156, Accuracy: 99.63%
# Epoch 10/15 - Loss: 0.0160, Accuracy: 99.45%
# Epoch 11/15 - Loss: 0.0225, Accuracy: 99.45%
# Epoch 12/15 - Loss: 0.0377, Accuracy: 98.53%
# Epoch 13/15 - Loss: 0.0386, Accuracy: 98.35%
# Epoch 14/15 - Loss: 0.0643, Accuracy: 98.17%
# Epoch 15/15 - Loss: 0.0654, Accuracy: 97.80%
#
# Training ResNet34Classifier with seed 99 for 15 epochs...
# Epoch 1/15 - Loss: 0.8344, Accuracy: 71.06%
# Epoch 2/15 - Loss: 0.3499, Accuracy: 85.53%
# Epoch 3/15 - Loss: 0.2789, Accuracy: 89.19%
# Epoch 4/15 - Loss: 0.1954, Accuracy: 92.67%
# Epoch 5/15 - Loss: 0.0962, Accuracy: 97.44%
# Epoch 6/15 - Loss: 0.0607, Accuracy: 97.99%
# Epoch 7/15 - Loss: 0.0890, Accuracy: 96.89%
# Epoch 8/15 - Loss: 0.0764, Accuracy: 97.25%
# Epoch 9/15 - Loss: 0.0664, Accuracy: 96.89%
# Epoch 10/15 - Loss: 0.0436, Accuracy: 98.17%
# Epoch 11/15 - Loss: 0.0331, Accuracy: 98.72%
# Epoch 12/15 - Loss: 0.0170, Accuracy: 99.63%
# Epoch 13/15 - Loss: 0.0164, Accuracy: 99.82%
# Epoch 14/15 - Loss: 0.0230, Accuracy: 99.08%
# Epoch 15/15 - Loss: 0.0082, Accuracy: 99.63%
#
# Training ResNet50Classifier with seed 99 for 15 epochs...
# Epoch 1/15 - Loss: 0.6469, Accuracy: 72.34%
# Epoch 2/15 - Loss: 0.3549, Accuracy: 85.71%
# Epoch 3/15 - Loss: 0.2439, Accuracy: 91.39%
# Epoch 4/15 - Loss: 0.1563, Accuracy: 93.41%
# Epoch 5/15 - Loss: 0.0679, Accuracy: 97.44%
# Epoch 6/15 - Loss: 0.0699, Accuracy: 97.25%
# Epoch 7/15 - Loss: 0.1097, Accuracy: 95.60%
# Epoch 8/15 - Loss: 0.0903, Accuracy: 96.89%
# Epoch 9/15 - Loss: 0.0727, Accuracy: 97.80%
# Epoch 10/15 - Loss: 0.0798, Accuracy: 97.07%
# Epoch 11/15 - Loss: 0.1220, Accuracy: 96.52%
# Epoch 12/15 - Loss: 0.1505, Accuracy: 93.96%
# Epoch 13/15 - Loss: 0.0646, Accuracy: 97.07%
# Epoch 14/15 - Loss: 0.0481, Accuracy: 98.72%
# Epoch 15/15 - Loss: 0.0271, Accuracy: 99.27%
#
# Training MobileNetV2Classifier with seed 99 for 15 epochs...
# Epoch 1/15 - Loss: 0.5459, Accuracy: 78.21%
# Epoch 2/15 - Loss: 0.3447, Accuracy: 86.45%
# Epoch 3/15 - Loss: 0.1740, Accuracy: 94.14%
# Epoch 4/15 - Loss: 0.0653, Accuracy: 97.99%
# Epoch 5/15 - Loss: 0.0582, Accuracy: 98.35%
# Epoch 6/15 - Loss: 0.0670, Accuracy: 97.80%
# Epoch 7/15 - Loss: 0.1152, Accuracy: 95.42%
# Epoch 8/15 - Loss: 0.0743, Accuracy: 96.34%
# Epoch 9/15 - Loss: 0.0408, Accuracy: 98.35%
# Epoch 10/15 - Loss: 0.0396, Accuracy: 98.90%
# Epoch 11/15 - Loss: 0.0432, Accuracy: 98.17%
# Epoch 12/15 - Loss: 0.0312, Accuracy: 99.45%
# Epoch 13/15 - Loss: 0.0325, Accuracy: 98.90%
# Epoch 14/15 - Loss: 0.0153, Accuracy: 99.45%
# Epoch 15/15 - Loss: 0.0217, Accuracy: 98.72%
#
# Training EfficientNetB0Classifier with seed 99 for 15 epochs...
# Epoch 1/15 - Loss: 0.4984, Accuracy: 76.19%
# Epoch 2/15 - Loss: 0.2001, Accuracy: 91.94%
# Epoch 3/15 - Loss: 0.1006, Accuracy: 96.52%
# Epoch 4/15 - Loss: 0.0926, Accuracy: 97.44%
# Epoch 5/15 - Loss: 0.0454, Accuracy: 98.53%
# Epoch 6/15 - Loss: 0.0291, Accuracy: 98.72%
# Epoch 7/15 - Loss: 0.0595, Accuracy: 97.99%
# Epoch 8/15 - Loss: 0.0515, Accuracy: 98.53%
# Epoch 9/15 - Loss: 0.0478, Accuracy: 97.80%
# Epoch 10/15 - Loss: 0.1064, Accuracy: 97.07%
# Epoch 11/15 - Loss: 0.0513, Accuracy: 98.17%
# Epoch 12/15 - Loss: 0.0402, Accuracy: 98.90%
# Epoch 13/15 - Loss: 0.0376, Accuracy: 99.27%
# Epoch 14/15 - Loss: 0.0214, Accuracy: 99.27%
# Epoch 15/15 - Loss: 0.0164, Accuracy: 99.63%
#
# Training DenseNet201Classifier with seed 99 for 15 epochs...
# Epoch 1/15 - Loss: 0.5292, Accuracy: 72.53%
# Epoch 2/15 - Loss: 0.3504, Accuracy: 87.18%
# Epoch 3/15 - Loss: 0.2597, Accuracy: 89.19%
# Epoch 4/15 - Loss: 0.1743, Accuracy: 93.41%
# Epoch 5/15 - Loss: 0.1194, Accuracy: 95.60%
# Epoch 6/15 - Loss: 0.0994, Accuracy: 95.79%
# Epoch 7/15 - Loss: 0.0709, Accuracy: 97.99%
# Epoch 8/15 - Loss: 0.0705, Accuracy: 97.25%
# Epoch 9/15 - Loss: 0.1055, Accuracy: 96.70%
# Epoch 10/15 - Loss: 0.1146, Accuracy: 95.79%
# Epoch 11/15 - Loss: 0.1120, Accuracy: 96.15%
# Epoch 12/15 - Loss: 0.0680, Accuracy: 97.99%
# Epoch 13/15 - Loss: 0.0408, Accuracy: 98.72%
# Epoch 14/15 - Loss: 0.0266, Accuracy: 99.63%
# Epoch 15/15 - Loss: 0.0329, Accuracy: 98.53%
#
# Training ShuffleNetClassifier with seed 99 for 15 epochs...
# Epoch 1/15 - Loss: 0.6195, Accuracy: 73.08%
# Epoch 2/15 - Loss: 0.4451, Accuracy: 73.08%
# Epoch 3/15 - Loss: 0.3145, Accuracy: 73.26%
# Epoch 4/15 - Loss: 0.2410, Accuracy: 89.56%
# Epoch 5/15 - Loss: 0.1732, Accuracy: 98.35%
# Epoch 6/15 - Loss: 0.1056, Accuracy: 99.27%
# Epoch 7/15 - Loss: 0.0451, Accuracy: 99.82%
# Epoch 8/15 - Loss: 0.0209, Accuracy: 99.82%
# Epoch 9/15 - Loss: 0.0085, Accuracy: 100.00%
# Epoch 10/15 - Loss: 0.0062, Accuracy: 100.00%
# Epoch 11/15 - Loss: 0.0034, Accuracy: 100.00%
# Epoch 12/15 - Loss: 0.0028, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0022, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0020, Accuracy: 100.00%
# Epoch 15/15 - Loss: 0.0021, Accuracy: 100.00%
#
# Training GoogLeNetClassifier with seed 99 for 15 epochs...
# Epoch 1/15 - Loss: 0.4467, Accuracy: 81.32%
# Epoch 2/15 - Loss: 0.2431, Accuracy: 90.11%
# Epoch 3/15 - Loss: 0.1178, Accuracy: 95.60%
# Epoch 4/15 - Loss: 0.0915, Accuracy: 96.34%
# Epoch 5/15 - Loss: 0.0864, Accuracy: 96.89%
# Epoch 6/15 - Loss: 0.0344, Accuracy: 99.27%
# Epoch 7/15 - Loss: 0.0171, Accuracy: 99.63%
# Epoch 8/15 - Loss: 0.0276, Accuracy: 98.90%
# Epoch 9/15 - Loss: 0.0290, Accuracy: 99.08%
# Epoch 10/15 - Loss: 0.0678, Accuracy: 97.99%
# Epoch 11/15 - Loss: 0.0843, Accuracy: 97.07%
# Epoch 12/15 - Loss: 0.0828, Accuracy: 97.25%
# Epoch 13/15 - Loss: 0.0763, Accuracy: 97.25%
# Epoch 14/15 - Loss: 0.0571, Accuracy: 98.72%
# Epoch 15/15 - Loss: 0.0440, Accuracy: 98.53%
# <class 'numpy.ndarray'>
# float32
# True
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.35it/s]
# DES Accuracy: 89.74%  | F1: 85.83%  | AUC: nan%
# PGD - Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.26it/s]
# DES Accuracy: 89.10%  | F1: 85.83%  | AUC: nan%
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:20<00:00,  7.68it/s]
#  Suspected Attacked Model Statistics:
#  - Model #1: 5/156 (3.21%)
#  Suspected attacked model name: ResNet34Classifier
#  - Model #0: 118/156 (75.64%)
#  Suspected attacked model name: ResNet18Classifier
#  - Model #4: 9/156 (5.77%)
#  Suspected attacked model name: EfficientNetB0Classifier
#  - Model #2: 9/156 (5.77%)
#  Suspected attacked model name: ResNet50Classifier
#  - Model #5: 8/156 (5.13%)
#  Suspected attacked model name: DenseNet201Classifier
#  - Model #7: 2/156 (1.28%)
#  Suspected attacked model name: GoogLeNetClassifier
#  - Model #6: 4/156 (2.56%)
#  Suspected attacked model name: ShuffleNetClassifier
#  - Model #3: 1/156 (0.64%)
#  Suspected attacked model name: MobileNetV2Classifier
# DES Accuracy: 89.10%  | F1: 85.59%  | AUC: nan%
#
# --- Seed: 102 ---
#
# Training ResNet18Classifier with seed 102 for 15 epochs...
# Epoch 1/15 - Loss: 0.6486, Accuracy: 70.70%
# Epoch 2/15 - Loss: 0.3206, Accuracy: 88.28%
# Epoch 3/15 - Loss: 0.2019, Accuracy: 92.86%
# Epoch 4/15 - Loss: 0.0970, Accuracy: 96.15%
# Epoch 5/15 - Loss: 0.0442, Accuracy: 98.90%
# Epoch 6/15 - Loss: 0.0554, Accuracy: 98.35%
# Epoch 7/15 - Loss: 0.1028, Accuracy: 96.70%
# Epoch 8/15 - Loss: 0.0268, Accuracy: 99.27%
# Epoch 9/15 - Loss: 0.0256, Accuracy: 99.27%
# Epoch 10/15 - Loss: 0.0104, Accuracy: 99.63%
# Epoch 11/15 - Loss: 0.0042, Accuracy: 100.00%
# Epoch 12/15 - Loss: 0.0013, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0012, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0012, Accuracy: 100.00%
# Epoch 15/15 - Loss: 0.0006, Accuracy: 100.00%
#
# Training ResNet34Classifier with seed 102 for 15 epochs...
# Epoch 1/15 - Loss: 0.8237, Accuracy: 66.67%
# Epoch 2/15 - Loss: 0.3209, Accuracy: 87.73%
# Epoch 3/15 - Loss: 0.2781, Accuracy: 89.74%
# Epoch 4/15 - Loss: 0.2243, Accuracy: 90.48%
# Epoch 5/15 - Loss: 0.1384, Accuracy: 94.51%
# Epoch 6/15 - Loss: 0.1168, Accuracy: 95.79%
# Epoch 7/15 - Loss: 0.1353, Accuracy: 93.59%
# Epoch 8/15 - Loss: 0.1304, Accuracy: 94.87%
# Epoch 9/15 - Loss: 0.0601, Accuracy: 98.35%
# Epoch 10/15 - Loss: 0.0283, Accuracy: 99.45%
# Epoch 11/15 - Loss: 0.0232, Accuracy: 99.63%
# Epoch 12/15 - Loss: 0.0406, Accuracy: 98.72%
# Epoch 13/15 - Loss: 0.1237, Accuracy: 96.70%
# Epoch 14/15 - Loss: 0.0642, Accuracy: 98.53%
# Epoch 15/15 - Loss: 0.0419, Accuracy: 98.72%
#
# Training ResNet50Classifier with seed 102 for 15 epochs...
# Epoch 1/15 - Loss: 0.6452, Accuracy: 72.34%
# Epoch 2/15 - Loss: 0.3954, Accuracy: 83.15%
# Epoch 3/15 - Loss: 0.2512, Accuracy: 88.46%
# Epoch 4/15 - Loss: 0.2203, Accuracy: 91.03%
# Epoch 5/15 - Loss: 0.1615, Accuracy: 93.59%
# Epoch 6/15 - Loss: 0.0889, Accuracy: 96.52%
# Epoch 7/15 - Loss: 0.0958, Accuracy: 97.07%
# Epoch 8/15 - Loss: 0.0404, Accuracy: 98.72%
# Epoch 9/15 - Loss: 0.0369, Accuracy: 98.53%
# Epoch 10/15 - Loss: 0.1006, Accuracy: 96.34%
# Epoch 11/15 - Loss: 0.0612, Accuracy: 97.44%
# Epoch 12/15 - Loss: 0.1051, Accuracy: 95.60%
# Epoch 13/15 - Loss: 0.1415, Accuracy: 93.77%
# Epoch 14/15 - Loss: 0.1027, Accuracy: 96.15%
# Epoch 15/15 - Loss: 0.0479, Accuracy: 98.35%
#
# Training MobileNetV2Classifier with seed 102 for 15 epochs...
# Epoch 1/15 - Loss: 0.5389, Accuracy: 74.91%
# Epoch 2/15 - Loss: 0.2524, Accuracy: 88.46%
# Epoch 3/15 - Loss: 0.0930, Accuracy: 97.07%
# Epoch 4/15 - Loss: 0.0356, Accuracy: 98.90%
# Epoch 5/15 - Loss: 0.0503, Accuracy: 98.35%
# Epoch 6/15 - Loss: 0.0681, Accuracy: 97.62%
# Epoch 7/15 - Loss: 0.0554, Accuracy: 97.99%
# Epoch 8/15 - Loss: 0.0496, Accuracy: 98.17%
# Epoch 9/15 - Loss: 0.0267, Accuracy: 99.08%
# Epoch 10/15 - Loss: 0.0241, Accuracy: 99.45%
# Epoch 11/15 - Loss: 0.0351, Accuracy: 98.72%
# Epoch 12/15 - Loss: 0.0759, Accuracy: 97.25%
# Epoch 13/15 - Loss: 0.0290, Accuracy: 99.27%
# Epoch 14/15 - Loss: 0.0298, Accuracy: 98.72%
# Epoch 15/15 - Loss: 0.0199, Accuracy: 99.45%
#
# Training EfficientNetB0Classifier with seed 102 for 15 epochs...
# Epoch 1/15 - Loss: 0.5053, Accuracy: 76.92%
# Epoch 2/15 - Loss: 0.1952, Accuracy: 92.31%
# Epoch 3/15 - Loss: 0.0790, Accuracy: 97.99%
# Epoch 4/15 - Loss: 0.0892, Accuracy: 97.25%
# Epoch 5/15 - Loss: 0.0546, Accuracy: 98.35%
# Epoch 6/15 - Loss: 0.0579, Accuracy: 97.80%
# Epoch 7/15 - Loss: 0.0359, Accuracy: 98.53%
# Epoch 8/15 - Loss: 0.0629, Accuracy: 97.99%
# Epoch 9/15 - Loss: 0.0303, Accuracy: 98.90%
# Epoch 10/15 - Loss: 0.0342, Accuracy: 99.08%
# Epoch 11/15 - Loss: 0.0205, Accuracy: 99.27%
# Epoch 12/15 - Loss: 0.0323, Accuracy: 98.90%
# Epoch 13/15 - Loss: 0.0282, Accuracy: 98.72%
# Epoch 14/15 - Loss: 0.0533, Accuracy: 98.53%
# Epoch 15/15 - Loss: 0.0980, Accuracy: 97.62%
#
# Training DenseNet201Classifier with seed 102 for 15 epochs...
# Epoch 1/15 - Loss: 0.5054, Accuracy: 75.27%
# Epoch 2/15 - Loss: 0.3211, Accuracy: 85.71%
# Epoch 3/15 - Loss: 0.2003, Accuracy: 91.94%
# Epoch 4/15 - Loss: 0.1141, Accuracy: 95.97%
# Epoch 5/15 - Loss: 0.0754, Accuracy: 97.62%
# Epoch 6/15 - Loss: 0.0807, Accuracy: 97.44%
# Epoch 7/15 - Loss: 0.0711, Accuracy: 97.44%
# Epoch 8/15 - Loss: 0.0521, Accuracy: 97.80%
# Epoch 9/15 - Loss: 0.0450, Accuracy: 98.72%
# Epoch 10/15 - Loss: 0.0444, Accuracy: 98.72%
# Epoch 11/15 - Loss: 0.0402, Accuracy: 98.72%
# Epoch 12/15 - Loss: 0.1250, Accuracy: 95.24%
# Epoch 13/15 - Loss: 0.0776, Accuracy: 97.07%
# Epoch 14/15 - Loss: 0.1047, Accuracy: 96.34%
# Epoch 15/15 - Loss: 0.0942, Accuracy: 96.34%
#
# Training ShuffleNetClassifier with seed 102 for 15 epochs...
# Epoch 1/15 - Loss: 0.6238, Accuracy: 72.16%
# Epoch 2/15 - Loss: 0.4387, Accuracy: 73.08%
# Epoch 3/15 - Loss: 0.3065, Accuracy: 81.87%
# Epoch 4/15 - Loss: 0.2230, Accuracy: 92.86%
# Epoch 5/15 - Loss: 0.1545, Accuracy: 95.24%
# Epoch 6/15 - Loss: 0.0848, Accuracy: 98.53%
# Epoch 7/15 - Loss: 0.0438, Accuracy: 99.82%
# Epoch 8/15 - Loss: 0.0235, Accuracy: 100.00%
# Epoch 9/15 - Loss: 0.0152, Accuracy: 99.82%
# Epoch 10/15 - Loss: 0.0313, Accuracy: 98.90%
# Epoch 11/15 - Loss: 0.0674, Accuracy: 97.80%
# Epoch 12/15 - Loss: 0.0543, Accuracy: 97.99%
# Epoch 13/15 - Loss: 0.0545, Accuracy: 98.35%
# Epoch 14/15 - Loss: 0.0183, Accuracy: 99.63%
# Epoch 15/15 - Loss: 0.0157, Accuracy: 99.63%
#
# Training GoogLeNetClassifier with seed 102 for 15 epochs...
# Epoch 1/15 - Loss: 0.4698, Accuracy: 78.21%
# Epoch 2/15 - Loss: 0.2198, Accuracy: 91.58%
# Epoch 3/15 - Loss: 0.1046, Accuracy: 95.97%
# Epoch 4/15 - Loss: 0.0544, Accuracy: 98.35%
# Epoch 5/15 - Loss: 0.0825, Accuracy: 96.34%
# Epoch 6/15 - Loss: 0.0753, Accuracy: 97.99%
# Epoch 7/15 - Loss: 0.0465, Accuracy: 98.35%
# Epoch 8/15 - Loss: 0.0255, Accuracy: 99.27%
# Epoch 9/15 - Loss: 0.0281, Accuracy: 99.27%
# Epoch 10/15 - Loss: 0.0321, Accuracy: 98.72%
# Epoch 11/15 - Loss: 0.0242, Accuracy: 99.08%
# Epoch 12/15 - Loss: 0.0222, Accuracy: 99.27%
# Epoch 13/15 - Loss: 0.0204, Accuracy: 99.27%
# Epoch 14/15 - Loss: 0.0663, Accuracy: 97.44%
# ...
# Epoch 11/15 - Loss: 0.0070, Accuracy: 100.00%
# Epoch 12/15 - Loss: 0.0050, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0031, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0031, Accuracy: 100.00%
# Epoch 15/15 - Loss: 0.0024, Accuracy: 100.00%
#
# Training GoogLeNetClassifier with seed 129 for 15 epochs...
# Epoch 1/15 - Loss: 0.4711, Accuracy: 77.84%
# Epoch 2/15 - Loss: 0.2912, Accuracy: 89.01%
# Epoch 3/15 - Loss: 0.1477, Accuracy: 93.96%
# Epoch 4/15 - Loss: 0.0951, Accuracy: 97.44%
# Epoch 5/15 - Loss: 0.0625, Accuracy: 98.53%
# Epoch 6/15 - Loss: 0.0681, Accuracy: 97.62%
# Epoch 7/15 - Loss: 0.0364, Accuracy: 99.08%
# Epoch 8/15 - Loss: 0.0464, Accuracy: 97.99%
# Epoch 9/15 - Loss: 0.0945, Accuracy: 97.25%
# Epoch 10/15 - Loss: 0.0483, Accuracy: 98.35%
# Epoch 11/15 - Loss: 0.0261, Accuracy: 99.45%
# Epoch 12/15 - Loss: 0.0266, Accuracy: 99.27%
# Epoch 13/15 - Loss: 0.0227, Accuracy: 99.27%
# Epoch 14/15 - Loss: 0.0065, Accuracy: 99.82%
# Epoch 15/15 - Loss: 0.0209, Accuracy: 99.63%
# <class 'numpy.ndarray'>
# float32
# True
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.27it/s]
# DES Accuracy: 90.38%  | F1: 87.29%  | AUC: nan%
# PGD - Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:25<00:00,  6.09it/s]
# DES Accuracy: 87.18%  | F1: 84.38%  | AUC: nan%
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:20<00:00,  7.48it/s]
#  Suspected Attacked Model Statistics:
#  - Model #6: 3/156 (1.92%)
#  Suspected attacked model name: ShuffleNetClassifier
#  - Model #0: 95/156 (60.90%)
#  Suspected attacked model name: ResNet18Classifier
#  - Model #1: 31/156 (19.87%)
#  Suspected attacked model name: ResNet34Classifier
#  - Model #4: 8/156 (5.13%)
#  Suspected attacked model name: EfficientNetB0Classifier
#  - Model #5: 6/156 (3.85%)
#  Suspected attacked model name: DenseNet201Classifier
#  - Model #2: 9/156 (5.77%)
#  Suspected attacked model name: ResNet50Classifier
#  - Model #7: 2/156 (1.28%)
#  Suspected attacked model name: GoogLeNetClassifier
#  - Model #3: 2/156 (1.28%)
#  Suspected attacked model name: MobileNetV2Classifier
# DES Accuracy: 88.46%  | F1: 85.75%  | AUC: nan%
#
# --- Seed: 141 ---
#
# Training ResNet18Classifier with seed 141 for 15 epochs...
# Epoch 1/15 - Loss: 0.6622, Accuracy: 75.82%
# Epoch 2/15 - Loss: 0.3536, Accuracy: 87.00%
# Epoch 3/15 - Loss: 0.2030, Accuracy: 91.21%
# Epoch 4/15 - Loss: 0.1101, Accuracy: 96.15%
# Epoch 5/15 - Loss: 0.0471, Accuracy: 98.53%
# Epoch 6/15 - Loss: 0.0549, Accuracy: 98.35%
# Epoch 7/15 - Loss: 0.0501, Accuracy: 98.72%
# Epoch 8/15 - Loss: 0.0188, Accuracy: 99.45%
# Epoch 9/15 - Loss: 0.0121, Accuracy: 99.82%
# Epoch 10/15 - Loss: 0.0079, Accuracy: 99.63%
# Epoch 11/15 - Loss: 0.0159, Accuracy: 99.63%
# Epoch 12/15 - Loss: 0.0114, Accuracy: 99.63%
# Epoch 13/15 - Loss: 0.0085, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0044, Accuracy: 100.00%
# Epoch 15/15 - Loss: 0.0036, Accuracy: 99.82%
#
# Training ResNet34Classifier with seed 141 for 15 epochs...
# Epoch 1/15 - Loss: 0.7545, Accuracy: 67.95%
# Epoch 2/15 - Loss: 0.4578, Accuracy: 82.78%
# Epoch 3/15 - Loss: 0.3104, Accuracy: 88.64%
# Epoch 4/15 - Loss: 0.2296, Accuracy: 91.21%
# Epoch 5/15 - Loss: 0.1254, Accuracy: 94.51%
# Epoch 6/15 - Loss: 0.1378, Accuracy: 94.51%
# Epoch 7/15 - Loss: 0.1075, Accuracy: 95.60%
# Epoch 8/15 - Loss: 0.0770, Accuracy: 97.62%
# Epoch 9/15 - Loss: 0.0701, Accuracy: 96.89%
# Epoch 10/15 - Loss: 0.1087, Accuracy: 96.70%
# Epoch 11/15 - Loss: 0.0780, Accuracy: 97.62%
# Epoch 12/15 - Loss: 0.0513, Accuracy: 98.72%
# Epoch 13/15 - Loss: 0.0167, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0484, Accuracy: 98.90%
# Epoch 15/15 - Loss: 0.0227, Accuracy: 98.90%
#
# Training ResNet50Classifier with seed 141 for 15 epochs...
# Epoch 1/15 - Loss: 0.6314, Accuracy: 72.53%
# Epoch 2/15 - Loss: 0.3757, Accuracy: 83.70%
# Epoch 3/15 - Loss: 0.3045, Accuracy: 88.64%
# Epoch 4/15 - Loss: 0.2137, Accuracy: 91.03%
# Epoch 5/15 - Loss: 0.1295, Accuracy: 93.96%
# Epoch 6/15 - Loss: 0.1039, Accuracy: 96.34%
# Epoch 7/15 - Loss: 0.1224, Accuracy: 95.42%
# Epoch 8/15 - Loss: 0.1840, Accuracy: 93.96%
# Epoch 9/15 - Loss: 0.1100, Accuracy: 95.05%
# Epoch 10/15 - Loss: 0.0371, Accuracy: 98.72%
# Epoch 11/15 - Loss: 0.0221, Accuracy: 99.45%
# Epoch 12/15 - Loss: 0.0332, Accuracy: 99.08%
# Epoch 13/15 - Loss: 0.0451, Accuracy: 98.35%
# Epoch 14/15 - Loss: 0.0516, Accuracy: 97.44%
# Epoch 15/15 - Loss: 0.0926, Accuracy: 95.97%
#
# Training MobileNetV2Classifier with seed 141 for 15 epochs...
# Epoch 1/15 - Loss: 0.5548, Accuracy: 75.27%
# Epoch 2/15 - Loss: 0.2339, Accuracy: 91.03%
# Epoch 3/15 - Loss: 0.1320, Accuracy: 95.05%
# Epoch 4/15 - Loss: 0.0647, Accuracy: 97.62%
# Epoch 5/15 - Loss: 0.0480, Accuracy: 98.90%
# Epoch 6/15 - Loss: 0.0289, Accuracy: 98.90%
# Epoch 7/15 - Loss: 0.0221, Accuracy: 99.27%
# Epoch 8/15 - Loss: 0.0521, Accuracy: 97.80%
# Epoch 9/15 - Loss: 0.0537, Accuracy: 97.62%
# Epoch 10/15 - Loss: 0.0573, Accuracy: 97.80%
# Epoch 11/15 - Loss: 0.0261, Accuracy: 99.08%
# Epoch 12/15 - Loss: 0.0180, Accuracy: 99.27%
# Epoch 13/15 - Loss: 0.0422, Accuracy: 98.53%
# Epoch 14/15 - Loss: 0.0646, Accuracy: 98.17%
# Epoch 15/15 - Loss: 0.0570, Accuracy: 97.62%
#
# Training EfficientNetB0Classifier with seed 141 for 15 epochs...
# Epoch 1/15 - Loss: 0.5088, Accuracy: 76.37%
# Epoch 2/15 - Loss: 0.2142, Accuracy: 91.94%
# Epoch 3/15 - Loss: 0.0830, Accuracy: 96.89%
# Epoch 4/15 - Loss: 0.0675, Accuracy: 97.25%
# Epoch 5/15 - Loss: 0.0598, Accuracy: 97.62%
# Epoch 6/15 - Loss: 0.0407, Accuracy: 98.72%
# Epoch 7/15 - Loss: 0.0237, Accuracy: 99.45%
# Epoch 8/15 - Loss: 0.0463, Accuracy: 97.62%
# Epoch 9/15 - Loss: 0.0948, Accuracy: 97.62%
# Epoch 10/15 - Loss: 0.0612, Accuracy: 98.35%
# Epoch 11/15 - Loss: 0.0383, Accuracy: 98.72%
# Epoch 12/15 - Loss: 0.0274, Accuracy: 98.90%
# Epoch 13/15 - Loss: 0.0280, Accuracy: 98.72%
# Epoch 14/15 - Loss: 0.0730, Accuracy: 97.44%
# Epoch 15/15 - Loss: 0.0387, Accuracy: 98.90%
#
# Training DenseNet201Classifier with seed 141 for 15 epochs...
# Epoch 1/15 - Loss: 0.5036, Accuracy: 78.94%
# Epoch 2/15 - Loss: 0.3196, Accuracy: 86.81%
# Epoch 3/15 - Loss: 0.2118, Accuracy: 90.66%
# Epoch 4/15 - Loss: 0.1321, Accuracy: 94.32%
# Epoch 5/15 - Loss: 0.0779, Accuracy: 96.89%
# Epoch 6/15 - Loss: 0.0899, Accuracy: 97.07%
# Epoch 7/15 - Loss: 0.0697, Accuracy: 97.44%
# Epoch 8/15 - Loss: 0.1014, Accuracy: 95.60%
# Epoch 9/15 - Loss: 0.1048, Accuracy: 96.15%
# Epoch 10/15 - Loss: 0.1563, Accuracy: 95.24%
# Epoch 11/15 - Loss: 0.1219, Accuracy: 95.60%
# Epoch 12/15 - Loss: 0.0489, Accuracy: 98.35%
# Epoch 13/15 - Loss: 0.0626, Accuracy: 97.80%
# Epoch 14/15 - Loss: 0.0918, Accuracy: 96.70%
# Epoch 15/15 - Loss: 0.0661, Accuracy: 97.62%
#
# Training ShuffleNetClassifier with seed 141 for 15 epochs...
# Epoch 1/15 - Loss: 0.6127, Accuracy: 73.81%
# Epoch 2/15 - Loss: 0.4240, Accuracy: 73.26%
# Epoch 3/15 - Loss: 0.2944, Accuracy: 78.21%
# Epoch 4/15 - Loss: 0.2193, Accuracy: 92.67%
# Epoch 5/15 - Loss: 0.1668, Accuracy: 96.15%
# Epoch 6/15 - Loss: 0.1113, Accuracy: 98.90%
# Epoch 7/15 - Loss: 0.0686, Accuracy: 99.45%
# Epoch 8/15 - Loss: 0.0368, Accuracy: 100.00%
# Epoch 9/15 - Loss: 0.0194, Accuracy: 100.00%
# Epoch 10/15 - Loss: 0.0093, Accuracy: 100.00%
# Epoch 11/15 - Loss: 0.0071, Accuracy: 100.00%
# Epoch 12/15 - Loss: 0.0042, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0082, Accuracy: 99.82%
# Epoch 14/15 - Loss: 0.0256, Accuracy: 98.90%
# Epoch 15/15 - Loss: 0.0565, Accuracy: 97.80%
#
# Training GoogLeNetClassifier with seed 141 for 15 epochs...
# Epoch 1/15 - Loss: 0.4236, Accuracy: 81.68%
# Epoch 2/15 - Loss: 0.2420, Accuracy: 91.58%
# Epoch 3/15 - Loss: 0.1262, Accuracy: 94.87%
# Epoch 4/15 - Loss: 0.1082, Accuracy: 95.79%
# Epoch 5/15 - Loss: 0.0762, Accuracy: 97.25%
# Epoch 6/15 - Loss: 0.0554, Accuracy: 98.17%
# Epoch 7/15 - Loss: 0.0564, Accuracy: 97.80%
# Epoch 8/15 - Loss: 0.0319, Accuracy: 98.90%
# Epoch 9/15 - Loss: 0.0259, Accuracy: 99.45%
# Epoch 10/15 - Loss: 0.0246, Accuracy: 99.08%
# Epoch 11/15 - Loss: 0.0125, Accuracy: 99.45%
# Epoch 12/15 - Loss: 0.0130, Accuracy: 99.45%
# Epoch 13/15 - Loss: 0.0273, Accuracy: 98.90%
# Epoch 14/15 - Loss: 0.0254, Accuracy: 98.72%
# Epoch 15/15 - Loss: 0.0486, Accuracy: 98.72%
# <class 'numpy.ndarray'>
# float32
# True
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:25<00:00,  6.08it/s]
# DES Accuracy: 87.18%  | F1: 81.58%  | AUC: nan%
# PGD - Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.29it/s]
# DES Accuracy: 78.21%  | F1: 63.00%  | AUC: nan%
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:20<00:00,  7.52it/s]
#  Suspected Attacked Model Statistics:
#  - Model #4: 9/156 (5.77%)
#  Suspected attacked model name: EfficientNetB0Classifier
#  - Model #0: 137/156 (87.82%)
#  Suspected attacked model name: ResNet18Classifier
#  - Model #2: 3/156 (1.92%)
#  Suspected attacked model name: ResNet50Classifier
#  - Model #3: 1/156 (0.64%)
#  Suspected attacked model name: MobileNetV2Classifier
#  - Model #7: 2/156 (1.28%)
#  Suspected attacked model name: GoogLeNetClassifier
#  - Model #1: 2/156 (1.28%)
#  Suspected attacked model name: ResNet34Classifier
#  - Model #5: 2/156 (1.28%)
#  Suspected attacked model name: DenseNet201Classifier
# DES Accuracy: 82.69%  | F1: 73.77%  | AUC: nan%
#
# --- Seed: 167 ---
#
# Training ResNet18Classifier with seed 167 for 15 epochs...
# Epoch 1/15 - Loss: 0.6383, Accuracy: 69.05%
# Epoch 2/15 - Loss: 0.3320, Accuracy: 86.08%
# Epoch 3/15 - Loss: 0.2173, Accuracy: 91.76%
# Epoch 4/15 - Loss: 0.1250, Accuracy: 95.05%
# Epoch 5/15 - Loss: 0.0675, Accuracy: 97.80%
# Epoch 6/15 - Loss: 0.0331, Accuracy: 99.08%
# Epoch 7/15 - Loss: 0.0192, Accuracy: 99.82%
# Epoch 8/15 - Loss: 0.0190, Accuracy: 99.27%
# Epoch 9/15 - Loss: 0.0185, Accuracy: 99.45%
# Epoch 10/15 - Loss: 0.0079, Accuracy: 100.00%
# Epoch 11/15 - Loss: 0.0215, Accuracy: 99.27%
# Epoch 12/15 - Loss: 0.0070, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0037, Accuracy: 100.00%
# Epoch 14/15 - Loss: 0.0027, Accuracy: 100.00%
# Epoch 15/15 - Loss: 0.0009, Accuracy: 100.00%
#
# Training ResNet34Classifier with seed 167 for 15 epochs...
# Epoch 1/15 - Loss: 0.7612, Accuracy: 69.41%
# Epoch 2/15 - Loss: 0.4105, Accuracy: 83.52%
# Epoch 3/15 - Loss: 0.3318, Accuracy: 86.45%
# Epoch 4/15 - Loss: 0.2044, Accuracy: 92.49%
# Epoch 5/15 - Loss: 0.1546, Accuracy: 94.51%
# Epoch 6/15 - Loss: 0.1273, Accuracy: 95.79%
# Epoch 7/15 - Loss: 0.1226, Accuracy: 94.51%
# Epoch 8/15 - Loss: 0.1443, Accuracy: 94.87%
# Epoch 9/15 - Loss: 0.1571, Accuracy: 93.96%
# Epoch 10/15 - Loss: 0.1064, Accuracy: 96.34%
# Epoch 11/15 - Loss: 0.0432, Accuracy: 98.53%
# Epoch 12/15 - Loss: 0.0365, Accuracy: 99.08%
# Epoch 13/15 - Loss: 0.0324, Accuracy: 98.90%
# Epoch 14/15 - Loss: 0.0345, Accuracy: 99.08%
# Epoch 15/15 - Loss: 0.0472, Accuracy: 98.35%
#
# Training ResNet50Classifier with seed 167 for 15 epochs...
# Epoch 1/15 - Loss: 0.5999, Accuracy: 72.71%
# Epoch 2/15 - Loss: 0.4129, Accuracy: 83.52%
# Epoch 3/15 - Loss: 0.3314, Accuracy: 88.28%
# Epoch 4/15 - Loss: 0.1911, Accuracy: 92.86%
# Epoch 5/15 - Loss: 0.1540, Accuracy: 94.32%
# Epoch 6/15 - Loss: 0.1830, Accuracy: 93.96%
# Epoch 7/15 - Loss: 0.1407, Accuracy: 95.05%
# Epoch 8/15 - Loss: 0.0700, Accuracy: 98.35%
# Epoch 9/15 - Loss: 0.0755, Accuracy: 98.17%
# Epoch 10/15 - Loss: 0.0589, Accuracy: 97.80%
# Epoch 11/15 - Loss: 0.0754, Accuracy: 97.25%
# Epoch 12/15 - Loss: 0.0524, Accuracy: 97.99%
# Epoch 13/15 - Loss: 0.0391, Accuracy: 98.35%
# Epoch 14/15 - Loss: 0.0261, Accuracy: 98.72%
# Epoch 15/15 - Loss: 0.0472, Accuracy: 98.53%
#
# Training MobileNetV2Classifier with seed 167 for 15 epochs...
# Epoch 1/15 - Loss: 0.5832, Accuracy: 77.11%
# Epoch 2/15 - Loss: 0.3085, Accuracy: 87.00%
# Epoch 3/15 - Loss: 0.1405, Accuracy: 94.69%
# Epoch 4/15 - Loss: 0.0728, Accuracy: 98.17%
# Epoch 5/15 - Loss: 0.1256, Accuracy: 94.87%
# Epoch 6/15 - Loss: 0.0741, Accuracy: 97.25%
# Epoch 7/15 - Loss: 0.0451, Accuracy: 98.53%
# Epoch 8/15 - Loss: 0.0254, Accuracy: 98.90%
# Epoch 9/15 - Loss: 0.0265, Accuracy: 99.08%
# Epoch 10/15 - Loss: 0.0214, Accuracy: 99.08%
# Epoch 11/15 - Loss: 0.0144, Accuracy: 99.45%
# Epoch 12/15 - Loss: 0.0508, Accuracy: 98.53%
# Epoch 13/15 - Loss: 0.0598, Accuracy: 98.53%
# Epoch 14/15 - Loss: 0.0275, Accuracy: 99.08%
# Epoch 15/15 - Loss: 0.0281, Accuracy: 98.90%
#
# Training EfficientNetB0Classifier with seed 167 for 15 epochs...
# Epoch 1/15 - Loss: 0.5198, Accuracy: 76.92%
# Epoch 2/15 - Loss: 0.2394, Accuracy: 91.03%
# Epoch 3/15 - Loss: 0.0931, Accuracy: 97.44%
# Epoch 4/15 - Loss: 0.0441, Accuracy: 97.80%
# Epoch 5/15 - Loss: 0.0405, Accuracy: 98.72%
# Epoch 6/15 - Loss: 0.0660, Accuracy: 96.52%
# Epoch 7/15 - Loss: 0.0655, Accuracy: 97.80%
# Epoch 8/15 - Loss: 0.0499, Accuracy: 98.17%
# Epoch 9/15 - Loss: 0.0341, Accuracy: 98.53%
# Epoch 10/15 - Loss: 0.0674, Accuracy: 96.89%
# Epoch 11/15 - Loss: 0.0426, Accuracy: 98.90%
# Epoch 12/15 - Loss: 0.0779, Accuracy: 97.62%
# Epoch 13/15 - Loss: 0.1067, Accuracy: 96.70%
# Epoch 14/15 - Loss: 0.0715, Accuracy: 97.99%
# Epoch 15/15 - Loss: 0.0287, Accuracy: 99.27%
#
# Training DenseNet201Classifier with seed 167 for 15 epochs...
# Epoch 1/15 - Loss: 0.4788, Accuracy: 76.56%
# Epoch 2/15 - Loss: 0.3448, Accuracy: 88.28%
# Epoch 3/15 - Loss: 0.2196, Accuracy: 92.49%
# Epoch 4/15 - Loss: 0.1124, Accuracy: 95.60%
# Epoch 5/15 - Loss: 0.0715, Accuracy: 97.07%
# Epoch 6/15 - Loss: 0.0504, Accuracy: 98.35%
# Epoch 7/15 - Loss: 0.0573, Accuracy: 97.99%
# Epoch 8/15 - Loss: 0.0795, Accuracy: 97.62%
# Epoch 9/15 - Loss: 0.0871, Accuracy: 97.07%
# Epoch 10/15 - Loss: 0.0650, Accuracy: 97.25%
# Epoch 11/15 - Loss: 0.1136, Accuracy: 96.15%
# Epoch 12/15 - Loss: 0.1374, Accuracy: 95.79%
# Epoch 13/15 - Loss: 0.0906, Accuracy: 97.07%
# Epoch 14/15 - Loss: 0.0731, Accuracy: 97.62%
# Epoch 15/15 - Loss: 0.0585, Accuracy: 99.08%
#
# Training ShuffleNetClassifier with seed 167 for 15 epochs...
# Epoch 1/15 - Loss: 0.6187, Accuracy: 73.81%
# Epoch 2/15 - Loss: 0.4339, Accuracy: 73.26%
# Epoch 3/15 - Loss: 0.3007, Accuracy: 77.66%
# Epoch 4/15 - Loss: 0.2271, Accuracy: 94.51%
# Epoch 5/15 - Loss: 0.1545, Accuracy: 97.99%
# Epoch 6/15 - Loss: 0.0794, Accuracy: 99.63%
# Epoch 7/15 - Loss: 0.0395, Accuracy: 100.00%
# Epoch 8/15 - Loss: 0.0182, Accuracy: 100.00%
# Epoch 9/15 - Loss: 0.0098, Accuracy: 100.00%
# Epoch 10/15 - Loss: 0.0071, Accuracy: 100.00%
# Epoch 11/15 - Loss: 0.0089, Accuracy: 99.82%
# Epoch 12/15 - Loss: 0.0325, Accuracy: 98.72%
# Epoch 13/15 - Loss: 0.1031, Accuracy: 95.24%
# Epoch 14/15 - Loss: 0.0697, Accuracy: 97.44%
# Epoch 15/15 - Loss: 0.0421, Accuracy: 99.08%
#
# Training GoogLeNetClassifier with seed 167 for 15 epochs...
# Epoch 1/15 - Loss: 0.5045, Accuracy: 70.70%
# Epoch 2/15 - Loss: 0.2331, Accuracy: 89.93%
# Epoch 3/15 - Loss: 0.1456, Accuracy: 94.32%
# Epoch 4/15 - Loss: 0.0824, Accuracy: 97.07%
# Epoch 5/15 - Loss: 0.0438, Accuracy: 98.53%
# Epoch 6/15 - Loss: 0.0257, Accuracy: 99.45%
# Epoch 7/15 - Loss: 0.0117, Accuracy: 99.82%
# Epoch 8/15 - Loss: 0.0075, Accuracy: 100.00%
# Epoch 9/15 - Loss: 0.0028, Accuracy: 100.00%
# Epoch 10/15 - Loss: 0.0030, Accuracy: 100.00%
# Epoch 11/15 - Loss: 0.0013, Accuracy: 100.00%
# Epoch 12/15 - Loss: 0.0040, Accuracy: 100.00%
# Epoch 13/15 - Loss: 0.0222, Accuracy: 99.27%
# Epoch 14/15 - Loss: 0.0415, Accuracy: 98.17%
# Epoch 15/15 - Loss: 0.1741, Accuracy: 94.32%
# <class 'numpy.ndarray'>
# float32
# True
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.35it/s]
# DES Accuracy: 88.46%  | F1: 83.75%  | AUC: nan%
# PGD - Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:24<00:00,  6.36it/s]
# DES Accuracy: 82.69%  | F1: 74.34%  | AUC: nan%
# 100%|█████████████████████████████████████████████████████████████████| 156/156 [00:20<00:00,  7.64it/s]
#  Suspected Attacked Model Statistics:
#  - Model #0: 141/156 (90.38%)
#  Suspected attacked model name: ResNet18Classifier
#  - Model #6: 5/156 (3.21%)
#  Suspected attacked model name: ShuffleNetClassifier
#  - Model #1: 8/156 (5.13%)
#  Suspected attacked model name: ResNet34Classifier
#  - Model #5: 2/156 (1.28%)
#  Suspected attacked model name: DenseNet201Classifier
# DES Accuracy: 87.18%  | F1: 82.60%  | AUC: nan%
#
# ⏱️ Total time for all seeds: 34.32 minutes

# %%
import pandas as pd 

summary = []

for clf_name, metrics_list in all_results.items():
    accs = [m['accuracy'] for m in metrics_list]
    f1s = [m['f1'] for m in metrics_list]
    aucs = [m['auc'] for m in metrics_list]

    summary.append({
        'Classifier': clf_name,
        'Accuracy': f"{np.mean(accs):.2f} ± {np.std(accs):.2f}",
        'F1': f"{np.mean(f1s):.2f} ± {np.std(f1s):.2f}",
        'AUC': f"{np.mean(aucs):.2f} ± {np.std(aucs):.2f}",
    })

df_summary = pd.DataFrame(summary)
print(df_summary)
# Out:
#                  Classifier       Accuracy             F1        AUC
# 0        ResNet18Classifier  81.41 ± 10.21  75.38 ± 12.17  nan ± nan
# 1        ResNet34Classifier   80.13 ± 8.91  74.98 ± 10.10  nan ± nan
# 2        ResNet50Classifier   82.31 ± 5.02   76.59 ± 6.91  nan ± nan
# 3     MobileNetV2Classifier   86.54 ± 3.07   82.17 ± 3.69  nan ± nan
# 4  EfficientNetB0Classifier   87.18 ± 2.20   82.75 ± 2.88  nan ± nan
# 5     DenseNet201Classifier   81.47 ± 8.36   75.96 ± 7.68  nan ± nan
# 6      ShuffleNetClassifier   84.81 ± 3.95   79.63 ± 5.02  nan ± nan
# 7       GoogLeNetClassifier   82.69 ± 4.27   77.84 ± 4.40  nan ± nan

# %%
import pandas as pd

summary = {
    'Metric': [],
    'Mean ± Std': []
}

for metric in ['accuracy', 'f1', 'auc']:
    values = des_metrics[metric]
    mean = np.nanmean(values)
    std = np.nanstd(values)
    summary['Metric'].append(metric.upper())
    summary['Mean ± Std'].append(f"{mean:.2f} ± {std:.2f}")

df_summary = pd.DataFrame(summary)
print("\n=== Final DES Performance (across seeds) ===")
print(df_summary)
# Out:
# === Final DES Performance (across seeds) ===
#      Metric    Mean ± Std
# 0  ACCURACY  89.87 ± 1.28
# 1        F1  86.28 ± 2.19
# 2       AUC     nan ± nan

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#f02263;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> Adversarial Attack Results</p></div>

# %%
import pandas as pd 

summary = []

for clf_name, metrics_list in attacked_results.items():
    accs = [m['accuracy'] for m in metrics_list]
    f1s = [m['f1'] for m in metrics_list]
    aucs = [m['auc'] for m in metrics_list]

    summary.append({
        'Classifier': clf_name,
        'Accuracy': f"{np.mean(accs):.2f} ± {np.std(accs):.2f}",
        'F1': f"{np.mean(f1s):.2f} ± {np.std(f1s):.2f}",
        'AUC': f"{np.mean(aucs):.2f} ± {np.std(aucs):.2f}",
    })

df_summary = pd.DataFrame(summary)
print(df_summary)
# Out:
#                  Classifier       Accuracy             F1        AUC
# 0        ResNet18Classifier  21.60 ± 10.94   19.82 ± 8.95  nan ± nan
# 1        ResNet34Classifier   78.78 ± 9.92  73.39 ± 10.85  nan ± nan
# 2        ResNet50Classifier   81.15 ± 6.95   75.74 ± 7.68  nan ± nan
# 3     MobileNetV2Classifier   85.71 ± 2.95   80.62 ± 4.08  nan ± nan
# 4  EfficientNetB0Classifier   86.73 ± 2.13   81.88 ± 3.09  nan ± nan
# 5     DenseNet201Classifier   80.19 ± 8.70   74.93 ± 7.94  nan ± nan
# 6      ShuffleNetClassifier   82.63 ± 4.89   77.18 ± 5.09  nan ± nan
# 7       GoogLeNetClassifier   81.47 ± 5.29   76.38 ± 5.42  nan ± nan

# %%
import pandas as pd

summary = {
    'Metric': [],
    'Mean ± Std': []
}

for metric in ['accuracy', 'f1', 'auc']:
    values = des_attacked_metrics[metric]
    mean = np.nanmean(values)
    std = np.nanstd(values)
    summary['Metric'].append(metric.upper())
    summary['Mean ± Std'].append(f"{mean:.2f} ± {std:.2f}")

df_summary = pd.DataFrame(summary)
print("\n=== Final Attacked DES Performance (across seeds) ===")
print(df_summary)
# Out:
# === Final Attacked DES Performance (across seeds) ===
#      Metric    Mean ± Std
# 0  ACCURACY  84.17 ± 3.65
# 1        F1  78.07 ± 6.76
# 2       AUC     nan ± nan

# %%
import pandas as pd

summary = {
    'Metric': [],
    'Mean ± Std': []
}

for metric in ['accuracy', 'f1', 'auc']:
    values = des_defense_metrics[metric]
    mean = np.nanmean(values)
    std = np.nanstd(values)
    summary['Metric'].append(metric.upper())
    summary['Mean ± Std'].append(f"{mean:.2f} ± {std:.2f}")

df_summary = pd.DataFrame(summary)
print("\n=== Final Attacked DES Performance (across seeds) ===")
print(df_summary)
# Out:
# === Final Attacked DES Performance (across seeds) ===
#      Metric    Mean ± Std
# 0  ACCURACY  88.40 ± 2.54
# 1        F1  84.29 ± 4.26
# 2       AUC     nan ± nan
